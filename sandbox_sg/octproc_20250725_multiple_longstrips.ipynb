# %% [markdown]
# # Process Multiple Long Strips

# %%
#%% imports
from pathlib import Path
# import json
# import configparser
import pprint
pp = pprint.PrettyPrinter(indent=4);
import time
import math
from collections import namedtuple

# # pip install slicerio
# import slicerio.server

# # packages for 3d
# #   # for OCT 3D stuff and using in jupyter
# #   - trame-jupyter-extension
# #   - trame
# #   - trame-vtk
# #   - trame-vuetify
# #   - ipywidgets

import matplotlib.pyplot as plt
import plotly.express as px

# interactive panels
import panel as pn
pn.extension('plotly');

import numpy as np
import pandas as pd
import addict

import cv2
import skimage
import scipy.signal

import pyvista as pv
from PIL import Image
import SimpleITK as sitk

# with vedo
#from vedo import dataurl, Volume, Text2D
import vedo
vedo.settings.default_backend = 'vtk'
#from vedo.applications import Slicer3DPlotter
import naatos_oct_tools.plotters.vedo_plotters as vedo_plotters
import naatos_oct_tools.plotters.sitk_plotters as sitk_plotters

import naatos_oct_tools.thorlabs_oct_file_reading
import naatos_oct_tools.oct_linear_scan_processing

import papermill
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='5bd7d636-dc63-415d-85fa-f59d92754bae'>
#   <div id="b2e59cb5-caa3-4539-82fc-12b57444c885" data-root-id="5bd7d636-dc63-415d-85fa-f59d92754bae" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"bec09228-1f01-4bf3-9aad-b90cd3a65161":{"version":"3.7.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"5bd7d636-dc63-415d-85fa-f59d92754bae"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"e087ab60-b32b-48ca-bf85-bb4a3d8f7cc5","attributes":{"plot_id":"5bd7d636-dc63-415d-85fa-f59d92754bae","comm_id":"7c5a57b479ae40589158a7436716f11f","client_comm_id":"e103586055db46369f55255ca9a1f98d"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"bec09228-1f01-4bf3-9aad-b90cd3a65161","roots":{"5bd7d636-dc63-415d-85fa-f59d92754bae":"b2e59cb5-caa3-4539-82fc-12b57444c885"},"root_ids":["5bd7d636-dc63-415d-85fa-f59d92754bae"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Plotly !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Magics to autoreload submodules when they are modified
# %load_ext autoreload
# %autoreload 2

# %%
#%% Test Record Excel
fname_excel = r'C:\Users\SimonGhionea\Global Health Labs, Inc\NAATOS Product Feasibility - TB V1 - General - Internal - Wax Valve\OCT\Test\OCT_wax_valve_test_record.xlsx';
dftests = pd.read_excel(
    fname_excel,
    skiprows=1
)
dftests = dftests.iloc[:,1:]
dftests.rename(columns={'Unnamed: 19':'Notes'},inplace=True)
dftests
# Out:
#      Test ID  Test date                     Test name                  Batch  \
# 0        NaN 2025-03-26       GHL_pyapp_20250326T1258  oven aging test day 1
# 1        NaN 2025-03-26       GHL_pyapp_20250326T1403  oven aging test day 1
# 2        NaN 2025-03-26       GHL_pyapp_20250326T1416  oven aging test day 1
# 3        NaN 2025-03-27       GHL_pyapp_20250327T1428  oven aging test day 2
# 4        NaN 2025-03-27       GHL_pyapp_20250327T1438  oven aging test day 2
# ..       ...        ...                           ...                    ...
# 217    212.0 2025-07-25  GHL_OldStriper_20250725T1509    722Valves0.325to0.4
# 218    213.0 2025-07-25  GHL_OldStriper_20250725T1514    722Valves0.325to0.4
# 219    214.0 2025-07-25  GHL_OldStriper_20250725T1528    722Valves0.325to0.4
# 220    215.0 2025-07-25  GHL_OldStriper_20250725T1532    722Valves0.325to0.4
# 221    216.0 2025-07-25  GHL_OldStriper_20250725T1519    722Valves0.325to0.4
#
#           Strip  Wax (mg/mm)                    Fixture  X, FOV  Y, FOV  \
# 0       strip 7          NaN             old, with tape     NaN     NaN
# 1      strip 10          NaN             old, with tape     NaN     NaN
# 2      strip 14          NaN             old, with tape     NaN     NaN
# 3       strip 7          NaN  old, with 3d print clamps     NaN     NaN
# 4      strip 10          NaN  old, with 3d print clamps     NaN     NaN
# ..          ...          ...                        ...     ...     ...
# 217  RG_7-22_12          NaN                        NaN     NaN     NaN
# 218  RG_7-22_18          NaN                        NaN     NaN     NaN
# 219  RG_7-22_10          NaN                        NaN     NaN     NaN
# 220   RG_7-22_9          NaN                        NaN     NaN     NaN
# 221   RG_7-22_6          NaN                        NaN     NaN     NaN
#
#      Z, FOV  ...  Right edge (mm)  Left edge (mm)  Strip length (mm)  \
# 0       NaN  ...              NaN             NaN                NaN
# 1       NaN  ...              NaN             NaN                NaN
# 2       NaN  ...              NaN             NaN                NaN
# 3       NaN  ...              NaN             NaN                NaN
# 4       NaN  ...              NaN             NaN                NaN
# ..      ...  ...              ...             ...                ...
# 217     NaN  ...              NaN             NaN                NaN
# 218     NaN  ...              NaN             NaN                NaN
# 219     NaN  ...              NaN             NaN                NaN
# 220     NaN  ...              NaN             NaN                NaN
# 221     NaN  ...              NaN             NaN                NaN
#
#      Speed/Sensitivity  Averaging (A-scan)  Refractive Index  File size (MB)  \
# 0                  NaN                 NaN               NaN             NaN
# 1                  NaN                 NaN               NaN             NaN
# 2                  NaN                 NaN               NaN             NaN
# 3                  NaN                 NaN               NaN             NaN
# 4                  NaN                 NaN               NaN             NaN
# ..                 ...                 ...               ...             ...
# 217                NaN                 NaN               NaN             NaN
# 218                NaN                 NaN               NaN             NaN
# 219                NaN                 NaN               NaN             NaN
# 220                NaN                 NaN               NaN             NaN
# 221                NaN                 NaN               NaN             NaN
#
#     Total size (GB)  ProcessingNotes  Notes
# 0               NaN              NaN    NaN
# 1               NaN              NaN    NaN
# 2               NaN              NaN    NaN
# 3               NaN              NaN    NaN
# 4               NaN              NaN    NaN
# ..              ...              ...    ...
# 217             NaN              NaN    NaN
# 218             NaN              NaN    NaN
# 219             NaN              NaN    NaN
# 220             NaN              NaN    NaN
# 221             NaN              NaN    NaN
#
# [222 rows x 24 columns]

# %%
#%% Filter The Tests To Process
dfmasks = [
    #(dftests['Test date']=='2025-06-11') | (dftests['Test date']=='2025-06-12'),
    
    #dftests['Test date']=='2025-07-11',
    
    #dftests['Test ID'].isin([47,65]) # strips flagged as bad from May batch

    # strips flagged as "extra bad" from June 09 Batch
    #dftests['Test ID'].isin([73,77,85,88,97,117])
    #dftests['Test ID'].isin([97]),

    #dftests['Test name']!='GHL_pyapp_20250512T',
    #dftests['ProcessingNotes'].str.startswith('done,2'),
    
    #dftests['Batch'].str.contains('July17n18Oldstriper') | dftests['Batch'].str.contains('July11WaxrobotStrips')
    dftests['Test date']=='2025-07-25',
    #dftests['Batch'].str.contains('Valve')
]

dffilt = dftests[np.all(dfmasks,axis=0)]
dffilt
# Out:
#      Test ID  Test date                     Test name                Batch  \
# 183    178.0 2025-07-25  GHL_OldStriper_20250725T1022  722Valves0.325to0.4
# 184    179.0 2025-07-25  GHL_OldStriper_20250725T1027  722Valves0.325to0.4
# 185    180.0 2025-07-25  GHL_OldStriper_20250725T1030  722Valves0.325to0.4
# 186    181.0 2025-07-25  GHL_OldStriper_20250725T1034  722Valves0.325to0.4
# 187    182.0 2025-07-25  GHL_OldStriper_20250725T1037  722Valves0.325to0.4
# 188    183.0 2025-07-25  GHL_OldStriper_20250725T1041  722Valves0.325to0.4
# 189    184.0 2025-07-25  GHL_OldStriper_20250725T1045  722Valves0.325to0.4
# 190    185.0 2025-07-25  GHL_OldStriper_20250725T1049  722Valves0.325to0.4
# 191    186.0 2025-07-25  GHL_OldStriper_20250725T1052  722Valves0.325to0.4
# 192    187.0 2025-07-25  GHL_OldStriper_20250725T1056  722Valves0.325to0.4
# 193    188.0 2025-07-25  GHL_OldStriper_20250725T1100  722Valves0.325to0.4
# 194    189.0 2025-07-25  GHL_OldStriper_20250725T1159  722Valves0.325to0.4
# 195    190.0 2025-07-25  GHL_OldStriper_20250725T1335  722Valves0.325to0.4
# 196    191.0 2025-07-25  GHL_OldStriper_20250725T1339  722Valves0.325to0.4
# 197    192.0 2025-07-25  GHL_OldStriper_20250725T1342  722Valves0.325to0.4
# 198    193.0 2025-07-25  GHL_OldStriper_20250725T1345  722Valves0.325to0.4
# 199    194.0 2025-07-25  GHL_OldStriper_20250725T1348  722Valves0.325to0.4
# 200    195.0 2025-07-25  GHL_OldStriper_20250725T1352  722Valves0.325to0.4
# 201    196.0 2025-07-25  GHL_OldStriper_20250725T1355  722Valves0.325to0.4
# 202    197.0 2025-07-25  GHL_OldStriper_20250725T1358  722Valves0.325to0.4
# 203    198.0 2025-07-25  GHL_OldStriper_20250725T1401  722Valves0.325to0.4
# 204    199.0 2025-07-25  GHL_OldStriper_20250725T1406  722Valves0.325to0.4
# 205    200.0 2025-07-25  GHL_OldStriper_20250725T1409  722Valves0.325to0.4
# 206    201.0 2025-07-25  GHL_OldStriper_20250725T1413  722Valves0.325to0.4
# 207    202.0 2025-07-25  GHL_OldStriper_20250725T1417  722Valves0.325to0.4
# 208    203.0 2025-07-25  GHL_OldStriper_20250725T1421  722Valves0.325to0.4
# 209    204.0 2025-07-25  GHL_OldStriper_20250725T1425  722Valves0.325to0.4
# 210    205.0 2025-07-25  GHL_OldStriper_20250725T1428  722Valves0.325to0.4
# 211    206.0 2025-07-25  GHL_OldStriper_20250725T1431  722Valves0.325to0.4
# 212    207.0 2025-07-25  GHL_OldStriper_20250725T1436  722Valves0.325to0.4
# 213    208.0 2025-07-25  GHL_OldStriper_20250725T1439  722Valves0.325to0.4
# 214    209.0 2025-07-25  GHL_OldStriper_20250725T1443  722Valves0.325to0.4
# 215    210.0 2025-07-25  GHL_OldStriper_20250725T1457  722Valves0.325to0.4
# 216    211.0 2025-07-25  GHL_OldStriper_20250725T1500  722Valves0.325to0.4
# 217    212.0 2025-07-25  GHL_OldStriper_20250725T1509  722Valves0.325to0.4
# 218    213.0 2025-07-25  GHL_OldStriper_20250725T1514  722Valves0.325to0.4
# 219    214.0 2025-07-25  GHL_OldStriper_20250725T1528  722Valves0.325to0.4
# 220    215.0 2025-07-25  GHL_OldStriper_20250725T1532  722Valves0.325to0.4
# 221    216.0 2025-07-25  GHL_OldStriper_20250725T1519  722Valves0.325to0.4
#
#               Strip  Wax (mg/mm) Fixture  X, FOV  Y, FOV  Z, FOV  ...  \
# 183      RG_7-22_26          NaN     NaN     NaN     NaN     NaN  ...
# 184      RG_7-22_59          NaN     NaN     NaN     NaN     NaN  ...
# 185      RG_7-22_51          NaN     NaN     NaN     NaN     NaN  ...
# 186      RG_7-22_46          NaN     NaN     NaN     NaN     NaN  ...
# 187      RG_7-22_37          NaN     NaN     NaN     NaN     NaN  ...
# 188      RG_7-22_48          NaN     NaN     NaN     NaN     NaN  ...
# 189      RG_7-22_24          NaN     NaN     NaN     NaN     NaN  ...
# 190       RG_7-22_2          NaN     NaN     NaN     NaN     NaN  ...
# 191      RG_7-22_14          NaN     NaN     NaN     NaN     NaN  ...
# 192       RG_7-22_1          NaN     NaN     NaN     NaN     NaN  ...
# 193      RG_7-22_31          NaN     NaN     NaN     NaN     NaN  ...
# 194      RG_7-22_33          NaN     NaN     NaN     NaN     NaN  ...
# 195      RG_7-22_34          NaN     NaN     NaN     NaN     NaN  ...
# 196      RG_7-22_35          NaN     NaN     NaN     NaN     NaN  ...
# 197      RG_7-22_54          NaN     NaN     NaN     NaN     NaN  ...
# 198      RG_7-22_57          NaN     NaN     NaN     NaN     NaN  ...
# 199      RG_7-22_58          NaN     NaN     NaN     NaN     NaN  ...
# 200      RG_7-22_64          NaN     NaN     NaN     NaN     NaN  ...
# 201      RG_7-22_47          NaN     NaN     NaN     NaN     NaN  ...
# 202      RG_7-22_65          NaN     NaN     NaN     NaN     NaN  ...
# 203      RG_7-22_63          NaN     NaN     NaN     NaN     NaN  ...
# 204      RG_7-22_62          NaN     NaN     NaN     NaN     NaN  ...
# 205      RG_7-22_66          NaN     NaN     NaN     NaN     NaN  ...
# 206      RG_7-22_60          NaN     NaN     NaN     NaN     NaN  ...
# 207      RG_7-22_42          NaN     NaN     NaN     NaN     NaN  ...
# 208      RG_7-22_39          NaN     NaN     NaN     NaN     NaN  ...
# 209      RG_7-22_43          NaN     NaN     NaN     NaN     NaN  ...
# 210      RG_7-22_44          NaN     NaN     NaN     NaN     NaN  ...
# 211      RG_7-22_30          NaN     NaN     NaN     NaN     NaN  ...
# 212  RG_7-22_75or25          NaN     NaN     NaN     NaN     NaN  ...
# 213      RG_7-22_78          NaN     NaN     NaN     NaN     NaN  ...
# 214      RG_7-22_23          NaN     NaN     NaN     NaN     NaN  ...
# 215      RG_7-22_50          NaN     NaN     NaN     NaN     NaN  ...
# 216       RG_7-22_4          NaN     NaN     NaN     NaN     NaN  ...
# 217      RG_7-22_12          NaN     NaN     NaN     NaN     NaN  ...
# 218      RG_7-22_18          NaN     NaN     NaN     NaN     NaN  ...
# 219      RG_7-22_10          NaN     NaN     NaN     NaN     NaN  ...
# 220       RG_7-22_9          NaN     NaN     NaN     NaN     NaN  ...
# 221       RG_7-22_6          NaN     NaN     NaN     NaN     NaN  ...
#
#      Right edge (mm)  Left edge (mm)  Strip length (mm)  Speed/Sensitivity  \
# 183              NaN             NaN                NaN                NaN
# 184              NaN             NaN                NaN                NaN
# 185              NaN             NaN                NaN                NaN
# 186              NaN             NaN                NaN                NaN
# 187              NaN             NaN                NaN                NaN
# 188              NaN             NaN                NaN                NaN
# 189              NaN             NaN                NaN                NaN
# 190              NaN             NaN                NaN                NaN
# 191              NaN             NaN                NaN                NaN
# 192              NaN             NaN                NaN                NaN
# 193              NaN             NaN                NaN                NaN
# 194              NaN             NaN                NaN                NaN
# 195              NaN             NaN                NaN                NaN
# 196              NaN             NaN                NaN                NaN
# 197              NaN             NaN                NaN                NaN
# 198              NaN             NaN                NaN                NaN
# 199              NaN             NaN                NaN                NaN
# 200              NaN             NaN                NaN                NaN
# 201              NaN             NaN                NaN                NaN
# 202              NaN             NaN                NaN                NaN
# 203              NaN             NaN                NaN                NaN
# 204              NaN             NaN                NaN                NaN
# 205              NaN             NaN                NaN                NaN
# 206              NaN             NaN                NaN                NaN
# 207              NaN             NaN                NaN                NaN
# 208              NaN             NaN                NaN                NaN
# 209              NaN             NaN                NaN                NaN
# 210              NaN             NaN                NaN                NaN
# 211              NaN             NaN                NaN                NaN
# 212              NaN             NaN                NaN                NaN
# 213              NaN             NaN                NaN                NaN
# 214              NaN             NaN                NaN                NaN
# 215              NaN             NaN                NaN                NaN
# 216              NaN             NaN                NaN                NaN
# 217              NaN             NaN                NaN                NaN
# 218              NaN             NaN                NaN                NaN
# 219              NaN             NaN                NaN                NaN
# 220              NaN             NaN                NaN                NaN
# 221              NaN             NaN                NaN                NaN
#
#      Averaging (A-scan)  Refractive Index  File size (MB) Total size (GB)  \
# 183                 NaN               NaN             NaN             NaN
# 184                 NaN               NaN             NaN             NaN
# 185                 NaN               NaN             NaN             NaN
# 186                 NaN               NaN             NaN             NaN
# 187                 NaN               NaN             NaN             NaN
# 188                 NaN               NaN             NaN             NaN
# 189                 NaN               NaN             NaN             NaN
# 190                 NaN               NaN             NaN             NaN
# 191                 NaN               NaN             NaN             NaN
# 192                 NaN               NaN             NaN             NaN
# 193                 NaN               NaN             NaN             NaN
# 194                 NaN               NaN             NaN             NaN
# 195                 NaN               NaN             NaN             NaN
# 196                 NaN               NaN             NaN             NaN
# 197                 NaN               NaN             NaN             NaN
# 198                 NaN               NaN             NaN             NaN
# 199                 NaN               NaN             NaN             NaN
# 200                 NaN               NaN             NaN             NaN
# 201                 NaN               NaN             NaN             NaN
# 202                 NaN               NaN             NaN             NaN
# 203                 NaN               NaN             NaN             NaN
# 204                 NaN               NaN             NaN             NaN
# 205                 NaN               NaN             NaN             NaN
# 206                 NaN               NaN             NaN             NaN
# 207                 NaN               NaN             NaN             NaN
# 208                 NaN               NaN             NaN             NaN
# 209                 NaN               NaN             NaN             NaN
# 210                 NaN               NaN             NaN             NaN
# 211                 NaN               NaN             NaN             NaN
# 212                 NaN               NaN             NaN             NaN
# 213                 NaN               NaN             NaN             NaN
# 214                 NaN               NaN             NaN             NaN
# 215                 NaN               NaN             NaN             NaN
# 216                 NaN               NaN             NaN             NaN
# 217                 NaN               NaN             NaN             NaN
# 218                 NaN               NaN             NaN             NaN
# 219                 NaN               NaN             NaN             NaN
# 220                 NaN               NaN             NaN             NaN
# 221                 NaN               NaN             NaN             NaN
#
#      ProcessingNotes                                              Notes
# 183              NaN                                                NaN
# 184              NaN                                                NaN
# 185              NaN                                                NaN
# 186              NaN                                                NaN
# 187              NaN                                                NaN
# 188              NaN                                                NaN
# 189              NaN                                                NaN
# 190              NaN                                                NaN
# 191              NaN                                                NaN
# 192              NaN                                                NaN
# 193              NaN                                                NaN
# 194              NaN                                                NaN
# 195              NaN                                                NaN
# 196              NaN                                                NaN
# 197              NaN                                                NaN
# 198              NaN                                                NaN
# 199              NaN                                                NaN
# 200              NaN                                                NaN
# 201              NaN                                                NaN
# 202              NaN                                                NaN
# 203              NaN                                                NaN
# 204              NaN                                                NaN
# 205              NaN                                                NaN
# 206              NaN                                                NaN
# 207              NaN  this strip has a fat section; modified transve...
# 208              NaN                                                NaN
# 209              NaN                                                NaN
# 210              NaN                                                NaN
# 211              NaN                                                NaN
# 212              NaN                                                NaN
# 213              NaN                                                NaN
# 214              NaN                                                NaN
# 215              NaN                                                NaN
# 216              NaN                                                NaN
# 217              NaN                                                NaN
# 218              NaN                                                NaN
# 219              NaN                                                NaN
# 220              NaN                                                NaN
# 221              NaN                                                NaN
#
# [39 rows x 24 columns]

# %%
#%% Load OCT study information
octstudies = [];
folder_octexport_root = Path(r'\\file.corp.ghlabs.org\Shared\Projects\NAATOS\V1\NAATOS_OCT_WORK\OCTExport')
#folder_octexport_root = Path(r'D:\SGProjects\NAATOS\OCTlocal')

# Load list of data
for idx,record in dffilt.iterrows():
    octstudy = naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder(record['Test name'],folder_octexport_root);
    octstudies.append(octstudy);
# Out:
# STUDY: GHL_OldStriper_20250725T1022
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1027
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1030
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1034
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1037
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1041
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1045
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1049
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1052
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1056
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1100
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1159
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1335
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1339
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1342
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1345
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1348
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1352
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1355
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1358
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1401
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1406
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1409
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1413
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1417
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1421
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1425
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1428
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1431
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1436
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1439
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1443
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1457
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1500
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1509
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1514
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1528
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1532
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250725T1519
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}

# %%
# Master Parameters
oct_scalar_min = 30;
oct_scalar_max = 60;

# %%
#%% Load OCTSTUDY object, and start some processing on it
for idx,octstudy in enumerate(octstudies):
    octstudy : naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder;
    print(octstudy)

    fname_merged_and_rescaled_volume = octstudy.folder_study_processed/'{:s}_STACKED_RESCALED_{:}to{:}_uint8.vtk'.format(octstudy.name,oct_scalar_min,oct_scalar_max);
    
    if(octstudy.study_info['study_num_oct_files']>0):
        # --Loading And Pre-Processing--
        if(fname_merged_and_rescaled_volume.exists()):
            pass;
            #print(f'Loading {fname_merged_and_rescaled_volume.name}')
            # Load the strip and merge into one volume
            #vdvol = vedo.Volume(pv.read(fname_merged_and_rescaled_volume));
            #octstudy.vdvol = vdvol;
        else:
            # Load OCT Data for this study
            octstudy.load_all_octs();


            # THESE WILL DO NOTHING IF ANTICIPATED OUTPUTS/ARTIFACTS ALREADY EXIST IN THE PROCESSED FOLDER

            # RGB Camera Images - Write them out as .jpg to processed folder
            naatos_oct_tools.oct_linear_scan_processing.process_rgbcamera_and_make_individual_images(octstudy);

            # RGB Camera Images - Make a montage and write out as .jpg to processed folder
            naatos_oct_tools.oct_linear_scan_processing.process_rgbcamera_and_make_montage_image(octstudy);
            #break;


            # IF MERGED STACKED AND RESCALED TO SCALAR RANGE FILE EXISTS, LOAD THAT; OTHERWISE PROCESS IT HERE
            octstudy.folder_study_processed.mkdir(exist_ok=True);
            fname = fname_merged_and_rescaled_volume;
            if(fname.exists()):
                print('Stacked volume byte-size .vtk file already exists, will not recreate.');
                print(fname);
            else:
                print(f'Generating merged and rescaled .vtk volume');
                # Generate merged and rescaled volume
                vdvol = octstudy.generate_merged_vdvol_and_rescaled(oct_scalar_min,oct_scalar_max);
                octstudy.vdvol = vdvol;
            
                # save this byte-adjusted volume
                vdvol.dataset.save(fname);
                        
            # Unload OCT Data for this study (we will still keep the vdvol)
            octstudy.unload_all_octdata();

        # --Detailed Image Processing--
        if hasattr(octstudy,'vdvol'):
            del octstudy.vdvol;

# %% [markdown]
# # (util) delete some items from processed folder

# %%
# Warning this can be destructive deleting processed data!!
if False:
    for idx,octstudy in enumerate(octstudies):
        print('~~~~~~~');
        print(octstudy.name);
        
        if False:
            fname = (octstudy.folder_study_processed/'along_strip_data_extracted.hdf5')
            if(fname.exists()):
                print('deleted',fname.name);
                fname.unlink();
            
            fname = (octstudy.folder_study_processed/'data_extracted.npz')
            if(fname.exists()):
                print('deleted',fname.name);
                fname.unlink();

            flist = octstudy.folder_study_processed.glob('figout*');
            for fname in flist:
                print('deleted',fname.name);
                fname.unlink();

            flist = octstudy.folder_study_processed.glob('processing_step*');
            for fname in flist:
                print('deleted',fname.name);
                fname.unlink();

        if False:
            # move files to a backup folder in the processed directory

            folder_backup = (octstudy.folder_study_processed/'_backup20250708');
            folder_backup.mkdir(exist_ok=True);

            fname = (octstudy.folder_study_processed/'along_strip_data_extracted.hdf5')
            if(fname.exists()):
                print('move to backup',fname.name);
                fname.rename(folder_backup/fname.name);
        
            fname = (octstudy.folder_study_processed/'data_extracted.npz')
            if(fname.exists()):
                print('move to backup',fname.name);
                fname.rename(folder_backup/fname.name);

            flist = octstudy.folder_study_processed.glob('figout*');
            for fname in flist:
                print('move to backup',fname.name);
                fname.rename(folder_backup/fname.name);

            flist = octstudy.folder_study_processed.glob('processing_step*');
            for fname in flist:
                print('move to backup',fname.name);
                fname.rename(folder_backup/fname.name);
        #break;

# %% [markdown]
# # (util) update excel index file

# %%
# Allow update of excel index file?
import openpyxl
workbook = None;
if True:
    # directly open excel file
    workbook = openpyxl.load_workbook(fname_excel);

    # open the proper sheet in the excel file
    #sheet = workbook.active
    sheet = workbook['Strip measurement'];

    # get the header
    hdrrow = 2;
    hdrcols = sheet[hdrrow];
    print(hdrcols)
    hdr = {c.value:cnt+1 for cnt,c in enumerate(hdrcols)};
    print(hdr)

    # go through each row, and look for matching octstudy object we have loaded in memory
    madeChanges = False;
    for row in sheet.iter_rows(min_row=hdrrow+3,min_col=hdrcols[0].column):
        record = {hdrcols[cnt].value:c.value for cnt,c in enumerate(row)}
        matchingoctstudy = [octstudy for octstudy in octstudies if octstudy.name==record["Test name"]]
        if len(matchingoctstudy)==1:
            print(record)
            print(octstudy.name)
            octstudy = matchingoctstudy[0]
            octstudy.load_first_oct();
            octdata = octstudy.octdatalist[0]
            cfg_oct_xml = octdata.cfg_oct_xml;

            # populate filesize
            row[hdr['Total size (GB)']-1].value = round(sum([f.stat().st_size for f in octstudy.folder_study.glob('*.oct')])/1e9,2);
            row[hdr['File size (MB)']-1].value = round((sum([f.stat().st_size for f in octstudy.folder_study.glob('*.oct')])/1e9)/octstudy.num_oct_files,2);

            # populate acquisition details
            pixelsize_x = float(cfg_oct_xml.Ocity.Image.PixelSpacing.SizeX.etElem.text)
            pixelsize_y = float(cfg_oct_xml.Ocity.Image.PixelSpacing.SizeY.etElem.text)
            pixelsize_z = float(cfg_oct_xml.Ocity.Image.PixelSpacing.SizeZ.etElem.text)
            totalsizemm_x = float(cfg_oct_xml.Ocity.Image.SizeReal.SizeX.etElem.text)
            totalsizemm_y = float(cfg_oct_xml.Ocity.Image.SizeReal.SizeY.etElem.text)
            totalsizemm_z = float(cfg_oct_xml.Ocity.Image.SizeReal.SizeZ.etElem.text)
            row[hdr['X, FOV']-1].value = totalsizemm_x;
            row[hdr['Y, FOV']-1].value = totalsizemm_y;
            row[hdr['Z, FOV']-1].value = totalsizemm_z;
            row[hdr['X, pixel size']-1].value = pixelsize_x*1e3;
            row[hdr['Y, pixel size']-1].value = pixelsize_y*1e3;
            row[hdr['Z, pixel size']-1].value = pixelsize_z*1e3;
            row[hdr['Angle']-1].value = float(cfg_oct_xml.Ocity.Image.Angle.etElem.text)
            row[hdr['Speed/Sensitivity']-1].value = cfg_oct_xml.Ocity.Instrument.DevicePresetDescription.etElem.text;
            row[hdr['Averaging (A-scan)']-1].value = int(cfg_oct_xml.Ocity.Acquisition.IntensityAveraging.AScans.etElem.text)
            row[hdr['Refractive Index']-1].value = round(float(cfg_oct_xml.Ocity.Acquisition.RefractiveIndex.etElem.text),1);

            if octstudy.has_json_info_file:
                jsoninfo = octstudy.json_info_file;
                row[hdr['Left edge (mm)']-1].value = jsoninfo['pos_leftmost_edge_center'];
                row[hdr['Right edge (mm)']-1].value = jsoninfo['pos_rightmost_edge_center'];
                row[hdr['Strip length (mm)']-1].value = jsoninfo['pos_rightmost_edge_center']-jsoninfo['pos_leftmost_edge_center'];

            # rescheck = octstudy.resultsCheck();
            # haveAllResults = not all([v is False for k,v in rescheck.items()])
            # #haveAllResults = haveAllResults and (len(rescheck['along_strip_data_extracted'])==5)
            # print('results done?',haveAllResults)
            # if(haveAllResults):
            #     row[hdr['ProcessingNotes']-1].value = 'done,{:d}'.format(len(rescheck['along_strip_data_extracted']))
            # else:
            #     row[hdr['ProcessingNotes']-1].value = ''
            # #break

            madeChanges = True

    if(madeChanges):
        # make a copy of the excel index
        fname_excel_copy = Path(fname_excel).parent/(Path(fname_excel).stem + time.strftime('_bak_%Y%m%dT%H%M.xlsx'))
        import shutil
        shutil.copy2(Path(fname_excel),fname_excel_copy);

        # then save the modified workbook on top of the old excel file
        workbook.save(fname_excel)
    else:
        print('No changes to excel index file made.');

    workbook.close();

# %% [markdown]
# # Call Notebooks - Processing A to D and E

# %%
#%% Load OCTSTUDY object, and start some processing on it
octstudies_to_run = [];
norunlist = [
    #'GHL_pyapp_20250508T1112','GHL_pyapp_20250508T1128','GHL_pyapp_20250508T1134','GHL_pyapp_20250508T1143'
]
forcerunlist = [
    #'GHL_pyapp_20250508T1151',
    #'GHL_pyapp_20250508T1601',
    #'GHL_pyapp_20250508T1608',
]
for idx,octstudy in enumerate(octstudies):
    octstudy : naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder;
    print('~~~~~~~');
    print(octstudy.name);
    rescheck = octstudy.resultsCheck();
    pp.pprint(rescheck)
    doWeRunTheNotebook = any([v is False for k,v in rescheck.items()])
    #doWeRunTheNotebook = doWeRunTheNotebook or ('/dfstepE' not in rescheck['along_strip_data_extracted']);
    doWeRunTheNotebook = doWeRunTheNotebook or ('/dfstepA' not in rescheck['along_strip_data_extracted']);
    print('Run?',doWeRunTheNotebook)
    if((doWeRunTheNotebook and octstudy.name not in norunlist) or (octstudy.name in forcerunlist)):
        octstudies_to_run.append(octstudy);
    # if(octstudy.name in forcerunlist):
    #     octstudies_to_run.append(octstudy);

# if(len(octstudies_to_run)>4):
#     #octstudies_to_run=octstudies_to_run[0:4];
#     #octstudies_to_run=octstudies_to_run[-4:];
#     print('only a subset');
#     norunlist = [
#         'GHL_pyapp_20250508T1112','GHL_pyapp_20250508T1128','GHL_pyapp_20250508T1134','GHL_pyapp_20250508T1143'
#     ]
#     octstudies_to_run = [s for s in octstudies_to_run if s.name not in norunlist ]
#     pass;

#octstudies_to_run = octstudies_to_run[0:20];

print('~~~~~~~');
print('We will run the processing on {:} octstudies.'.format(len(octstudies_to_run)))
print([x.name for x in octstudies_to_run])

# %% [markdown]
# # Prepare notebooks we will call

# %%
nbpaths = [
    #r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\octproc_20250615_process_a_longstrip.ipynb",
    #r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\octproc_20250721_process_a_longstrip.ipynb",
    r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\octproc_20250722_process_a_longstrip.ipynb",
];
for nbpath in nbpaths:
    print('Notebook:',Path(nbpath).name);
    parameters = papermill.inspect_notebook(nbpath)
    pp.pprint(parameters.keys());
# Out:
# Notebook: octproc_20250722_process_a_longstrip.ipynb
# dict_keys(['oct_scalar_min', 'oct_scalar_max', 'codename', 'study_name', 'folder_octexport_root', 'folder_figure_temp'])

# %% [markdown]
# # Call notebooks to process (Multiple-strips in parallel, concurrent futures)

# %%
import concurrent.futures

def run_notebook_on_an_octstudy(octstudy : naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder):

    folder_temp_path = Path(r'D:\TEMP\OCTtmp');
    folder_temp_path.mkdir(parents=True,exist_ok=True);

    # run each notebook we have defined to be run
    nnotebooks = len(nbpaths);
    for count,nbpath in enumerate(nbpaths):
        nbpath = Path(nbpath)
        nbpath_out = folder_temp_path/(nbpath.stem+'_OUT_{:s}.ipynb').format(octstudy.name)

        # execute a notebook
        print(f'Launching for {octstudy.name} the {count+1}/{nnotebooks} notebook {nbpath.name} ...')
        try:
            papermill.execute_notebook(
                input_path=nbpath,
                output_path=nbpath_out,
                parameters=dict(
                    folder_octexport_root=folder_octexport_root.as_posix(),
                    codename = Path(nbpath).name,
                    study_name=octstudy.name,
                    folder_figure_temp=nbpath_out.parent.as_posix()
                )
            )
            print(f'Finished for {octstudy.name} the {count+1}/{nnotebooks} notebook {nbpath.name} !')
        except Exception as e:
            print(f'FAILED for {octstudy.name} the {count+1}/{nnotebooks} notebook {nbpath.name} !')
            break;
    print(f'alldone for {octstudy.name}')


# Using concurrent.futures to handle multiprocessing
def run_in_parallel(num_processes):
    # with concurrent.futures.ProcessPoolExecutor(max_workers=num_processes) as executor:
    #     futures = [executor.submit(run_notebook_on_an_octstudy, octstudy) for octstudy in octstudies_to_run]
    #     for future in concurrent.futures.as_completed(futures):
    #         print(future.result())  # You can handle results or exceptions here
    with concurrent.futures.ThreadPoolExecutor(max_workers=num_processes) as executor:
        futures = [executor.submit(run_notebook_on_an_octstudy, octstudy) for octstudy in octstudies_to_run]
        for future in concurrent.futures.as_completed(futures):
            print(future.result());

# Example usage
num_processes = 6;  # Number of parallel processes
run_in_parallel(num_processes);
# Out:
# Launching for GHL_WaxRobot_20250711T1438 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Launching for GHL_WaxRobot_20250711T1442 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Launching for GHL_WaxRobot_20250711T1501 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Launching for GHL_WaxRobot_20250711T1513 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Launching for GHL_WaxRobot_20250711T1519 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Launching for GHL_OldStriper_20250722T1202 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 7.70 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 8.01 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 7.91 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 9.44 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 20.56 sec, over 25% limit. Backing off to 120 sec
# Autosave too slow: 22.35 sec, over 25% limit. Backing off to 120 sec
# Finished for GHL_OldStriper_20250722T1202 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1202
# Launching for GHL_OldStriper_20250722T1206 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# None
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 7.67 sec, over 25% limit. Backing off to 60 sec
# Finished for GHL_WaxRobot_20250711T1438 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_WaxRobot_20250711T1438
# None
# Launching for GHL_OldStriper_20250722T1213 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 19.83 sec, over 25% limit. Backing off to 120 sec
# Autosave too slow: 10.80 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 9.71 sec, over 25% limit. Backing off to 60 sec
# Finished for GHL_OldStriper_20250722T1206 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1206
# None
# Launching for GHL_OldStriper_20250722T1216 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 19.00 sec, over 25% limit. Backing off to 120 sec
# Finished for GHL_OldStriper_20250722T1213 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1213
# None
# Launching for GHL_OldStriper_20250722T1220 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_WaxRobot_20250711T1501 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_WaxRobot_20250711T1501
# None
# Launching for GHL_OldStriper_20250722T1223 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 7.81 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 34.83 sec, over 25% limit. Backing off to 240 sec
# Finished for GHL_OldStriper_20250722T1216 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1216
# None
# Launching for GHL_OldStriper_20250722T1226 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 9.67 sec, over 25% limit. Backing off to 60 sec
# Finished for GHL_WaxRobot_20250711T1442 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_WaxRobot_20250711T1442
# None
# Launching for GHL_OldStriper_20250722T1229 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1223 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1223
# None
# Launching for GHL_OldStriper_20250722T1232 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1220 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1220
# None
# Launching for GHL_OldStriper_20250722T1235 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 31.57 sec, over 25% limit. Backing off to 240 sec
# Autosave too slow: 14.59 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 19.01 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 7.74 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 8.65 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 338.83 sec, over 25% limit. Backing off to 120 sec
# Autosave too slow: 245.88 sec, over 25% limit. Backing off to 120 sec
# Autosave too slow: 353.39 sec, over 25% limit. Backing off to 120 sec
# Autosave too slow: 37.53 sec, over 25% limit. Backing off to 240 sec
# Autosave too slow: 34.54 sec, over 25% limit. Backing off to 240 sec
# Autosave too slow: 185.02 sec, over 25% limit. Backing off to 240 sec
# Autosave too slow: 534.57 sec, over 25% limit. Backing off to 480 sec
# Autosave too slow: 543.23 sec, over 25% limit. Backing off to 120 sec
# Autosave too slow: 335.58 sec, over 25% limit. Backing off to 480 sec
# Autosave too slow: 520.95 sec, over 25% limit. Backing off to 480 sec
# Finished for GHL_OldStriper_20250722T1229 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1229
# None
# Launching for GHL_OldStriper_20250722T1239 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1226 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1226
# None
# Launching for GHL_OldStriper_20250722T1243 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_WaxRobot_20250711T1519 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_WaxRobot_20250711T1519
# None
# Launching for GHL_OldStriper_20250722T1254 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1235 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1235
# None
# Launching for GHL_OldStriper_20250722T1257 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1232 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1232
# None
# Launching for GHL_OldStriper_20250722T1300 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_WaxRobot_20250711T1513 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_WaxRobot_20250711T1513
# None
# Launching for GHL_OldStriper_20250722T1303 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1239 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1239
# None
# Launching for GHL_OldStriper_20250722T1306 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1243 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1243
# None
# Launching for GHL_OldStriper_20250722T1309 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1257 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1257
# Launching for GHL_OldStriper_20250722T1312 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# None
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1254 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1254
# None
# Launching for GHL_OldStriper_20250722T1318 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1303 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1303
# None
# Launching for GHL_OldStriper_20250722T1339 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1300 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1300
# None
# Launching for GHL_OldStriper_20250722T1342 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1306 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1306
# None
# Launching for GHL_OldStriper_20250722T1348 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1309 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1309
# None
# Launching for GHL_OldStriper_20250722T1351 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1318 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1318
# None
# Launching for GHL_OldStriper_20250722T1354 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1339 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1339
# None
# Launching for GHL_OldStriper_20250722T1357 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1312 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1312
# None
# Launching for GHL_OldStriper_20250722T1400 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 7.74 sec, over 25% limit. Backing off to 60 sec
# Finished for GHL_OldStriper_20250722T1342 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1342
# None
# Launching for GHL_OldStriper_20250722T1403 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1351 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1351
# None
# Launching for GHL_OldStriper_20250722T1406 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1348 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1348
# None
# Launching for GHL_OldStriper_20250722T1409 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1354 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1354
# Launching for GHL_OldStriper_20250722T1413 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# None
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1357 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1357
# None
# Launching for GHL_OldStriper_20250722T1418 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1403 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1403
# None
# Launching for GHL_OldStriper_20250722T1421 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1400 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1400
# None
# Finished for GHL_OldStriper_20250722T1409 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1409
# None
# Finished for GHL_OldStriper_20250722T1406 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1406
# None
# Finished for GHL_OldStriper_20250722T1413 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1413
# None
# Finished for GHL_OldStriper_20250722T1418 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1418
# None
# Finished for GHL_OldStriper_20250722T1421 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1421
# None
