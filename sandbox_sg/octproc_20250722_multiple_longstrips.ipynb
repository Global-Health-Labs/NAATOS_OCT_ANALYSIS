# %% [markdown]
# # Process Multiple Long Strips

# %%
#%% imports
from pathlib import Path
# import json
# import configparser
import pprint
pp = pprint.PrettyPrinter(indent=4);
import time
import math
from collections import namedtuple

# # pip install slicerio
# import slicerio.server

# # packages for 3d
# #   # for OCT 3D stuff and using in jupyter
# #   - trame-jupyter-extension
# #   - trame
# #   - trame-vtk
# #   - trame-vuetify
# #   - ipywidgets

import matplotlib.pyplot as plt
import plotly.express as px

# interactive panels
import panel as pn
pn.extension('plotly');

import numpy as np
import pandas as pd
import addict

import cv2
import skimage
import scipy.signal

import pyvista as pv
from PIL import Image
import SimpleITK as sitk

# with vedo
#from vedo import dataurl, Volume, Text2D
import vedo
vedo.settings.default_backend = 'vtk'
#from vedo.applications import Slicer3DPlotter
import naatos_oct_tools.plotters.vedo_plotters as vedo_plotters
import naatos_oct_tools.plotters.sitk_plotters as sitk_plotters

import naatos_oct_tools.thorlabs_oct_file_reading
import naatos_oct_tools.oct_linear_scan_processing

import papermill
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='9709399d-cba2-4956-b4b8-59da18da823a'>
#   <div id="b6f6ff72-3f54-475a-930f-6811bb6cf7aa" data-root-id="9709399d-cba2-4956-b4b8-59da18da823a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"47c6a8ce-5c08-4cda-82c2-31928f5ac0b5":{"version":"3.7.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"9709399d-cba2-4956-b4b8-59da18da823a"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"9e6c49e4-78af-4312-afac-98bb34963b18","attributes":{"plot_id":"9709399d-cba2-4956-b4b8-59da18da823a","comm_id":"bc0210374a31425aaa8c3f6243a9e9a6","client_comm_id":"b8f93272530644e5ad98edf394ac7199"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"47c6a8ce-5c08-4cda-82c2-31928f5ac0b5","roots":{"9709399d-cba2-4956-b4b8-59da18da823a":"b6f6ff72-3f54-475a-930f-6811bb6cf7aa"},"root_ids":["9709399d-cba2-4956-b4b8-59da18da823a"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Plotly !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Magics to autoreload submodules when they are modified
# %load_ext autoreload
# %autoreload 2

# %%
#%% Test Record Excel
fname_excel = r'C:\Users\SimonGhionea\Global Health Labs, Inc\NAATOS Product Feasibility - TB V1 - General - Internal - Wax Valve\OCT\Test\OCT_wax_valve_test_record.xlsx';
dftests = pd.read_excel(
    fname_excel,
    skiprows=1
)
dftests = dftests.iloc[:,1:]
dftests.rename(columns={'Unnamed: 19':'Notes'},inplace=True)
dftests
# Out:
#      Test ID  Test date                     Test name                  Batch  \
# 0        NaN 2025-03-26       GHL_pyapp_20250326T1258  oven aging test day 1
# 1        NaN 2025-03-26       GHL_pyapp_20250326T1403  oven aging test day 1
# 2        NaN 2025-03-26       GHL_pyapp_20250326T1416  oven aging test day 1
# 3        NaN 2025-03-27       GHL_pyapp_20250327T1428  oven aging test day 2
# 4        NaN 2025-03-27       GHL_pyapp_20250327T1438  oven aging test day 2
# ..       ...        ...                           ...                    ...
# 178    173.0 2025-07-22  GHL_OldStriper_20250722T1406    July17n18Oldstriper
# 179    174.0 2025-07-22  GHL_OldStriper_20250722T1409    July17n18Oldstriper
# 180    175.0 2025-07-22  GHL_OldStriper_20250722T1413    July17n18Oldstriper
# 181    176.0 2025-07-22  GHL_OldStriper_20250722T1418    July17n18Oldstriper
# 182    177.0 2025-07-22  GHL_OldStriper_20250722T1421    July17n18Oldstriper
#
#         Strip  Wax (mg/mm)                    Fixture  X, FOV  Y, FOV  Z, FOV  \
# 0     strip 7          NaN             old, with tape     NaN     NaN     NaN
# 1    strip 10          NaN             old, with tape     NaN     NaN     NaN
# 2    strip 14          NaN             old, with tape     NaN     NaN     NaN
# 3     strip 7          NaN  old, with 3d print clamps     NaN     NaN     NaN
# 4    strip 10          NaN  old, with 3d print clamps     NaN     NaN     NaN
# ..        ...          ...                        ...     ...     ...     ...
# 178   7-17_26          NaN                     Vacuum     NaN     NaN     NaN
# 179   7-17_23          NaN                     Vacuum     NaN     NaN     NaN
# 180   7-17_21          NaN                     Vacuum     NaN     NaN     NaN
# 181   7-17_19          NaN                     Vacuum     NaN     NaN     NaN
# 182   7-17_16          NaN                     Vacuum     NaN     NaN     NaN
#
#      ...  Right edge (mm)  Left edge (mm)  Strip length (mm)  \
# 0    ...              NaN             NaN                NaN
# 1    ...              NaN             NaN                NaN
# 2    ...              NaN             NaN                NaN
# 3    ...              NaN             NaN                NaN
# 4    ...              NaN             NaN                NaN
# ..   ...              ...             ...                ...
# 178  ...              NaN             NaN                NaN
# 179  ...              NaN             NaN                NaN
# 180  ...              NaN             NaN                NaN
# 181  ...              NaN             NaN                NaN
# 182  ...              NaN             NaN                NaN
#
#      Speed/Sensitivity  Averaging (A-scan)  Refractive Index  File size (MB)  \
# 0                  NaN                 NaN               NaN             NaN
# 1                  NaN                 NaN               NaN             NaN
# 2                  NaN                 NaN               NaN             NaN
# 3                  NaN                 NaN               NaN             NaN
# 4                  NaN                 NaN               NaN             NaN
# ..                 ...                 ...               ...             ...
# 178                NaN                 NaN               NaN             NaN
# 179                NaN                 NaN               NaN             NaN
# 180                NaN                 NaN               NaN             NaN
# 181                NaN                 NaN               NaN             NaN
# 182                NaN                 NaN               NaN             NaN
#
#     Total size (GB)  ProcessingNotes  Notes
# 0               NaN              NaN    NaN
# 1               NaN              NaN    NaN
# 2               NaN              NaN    NaN
# 3               NaN              NaN    NaN
# 4               NaN              NaN    NaN
# ..              ...              ...    ...
# 178             NaN              NaN    NaN
# 179             NaN              NaN    NaN
# 180             NaN              NaN    NaN
# 181             NaN              NaN    NaN
# 182             NaN              NaN    NaN
#
# [183 rows x 24 columns]

# %%
#%% Filter The Tests To Process
dfmasks = [
    #(dftests['Test date']=='2025-06-11') | (dftests['Test date']=='2025-06-12'),
    
    #dftests['Test date']=='2025-07-11',
    
    #dftests['Test ID'].isin([47,65]) # strips flagged as bad from May batch

    # strips flagged as "extra bad" from June 09 Batch
    #dftests['Test ID'].isin([73,77,85,88,97,117])
    #dftests['Test ID'].isin([97]),

    #dftests['Test name']!='GHL_pyapp_20250512T',
    #dftests['ProcessingNotes'].str.startswith('done,2'),
    
    dftests['Batch'].str.contains('July17n18Oldstriper')
    
    #dftests['Batch'].str.contains('Valve')
]

dffilt = dftests[np.all(dfmasks,axis=0)]
dffilt
# Out:
#      Test ID  Test date                     Test name                Batch  \
# 150    145.0 2025-07-22  GHL_OldStriper_20250722T1202  July17n18Oldstriper
# 175              NaN             NaN                NaN                NaN
# 176              NaN             NaN                NaN                NaN
# 177              NaN             NaN                NaN                NaN
# 178              NaN             NaN                NaN                NaN
# 179              NaN             NaN                NaN                NaN
# 180              NaN             NaN                NaN                NaN
# 181              NaN             NaN                NaN                NaN
# 182              NaN             NaN                NaN                NaN
#
#      Averaging (A-scan)  Refractive Index  File size (MB) Total size (GB)  \
# 150                 NaN               NaN             NaN             NaN
# 151                 NaN               NaN             NaN             NaN
# 152                 NaN               NaN             NaN             NaN
# 153                 NaN               NaN             NaN             NaN
# 154                 NaN               NaN             NaN             NaN
# 155                 NaN               NaN             NaN             NaN
# 156                 NaN               NaN             NaN             NaN
# 157                 NaN               NaN             NaN             NaN
# 158                 NaN               NaN             NaN             NaN
# 159                 NaN               NaN             NaN             NaN
# 160                 NaN               NaN             NaN             NaN
# 161                 NaN               NaN             NaN             NaN
# 162                 NaN               NaN             NaN             NaN
# 163                 NaN               NaN             NaN             NaN
# 164                 NaN               NaN             NaN             NaN
# 165                 NaN               NaN             NaN             NaN
# 166                 NaN               NaN             NaN             NaN
# 167                 NaN               NaN             NaN             NaN
# 168                 NaN               NaN             NaN             NaN
# 169                 NaN               NaN             NaN             NaN
# 170                 NaN               NaN             NaN             NaN
# 171                 NaN               NaN             NaN             NaN
# 172                 NaN               NaN             NaN             NaN
# 173                 NaN               NaN             NaN             NaN
# 174                 NaN               NaN             NaN             NaN
# 175                 NaN               NaN             NaN             NaN
# 176                 NaN               NaN             NaN             NaN
# 177                 NaN               NaN             NaN             NaN
# 178                 NaN               NaN             NaN             NaN
# 179                 NaN               NaN             NaN             NaN
# 180                 NaN               NaN             NaN             NaN
# 181                 NaN               NaN             NaN             NaN
# 182                 NaN               NaN             NaN             NaN
#
#      ProcessingNotes  Notes
# 150              NaN    NaN
# 151              NaN    NaN
# 152              NaN    NaN
# 153              NaN    NaN
# 154              NaN    NaN
# 155              NaN    NaN
# 156              NaN    NaN
# 157              NaN    NaN
# 158              NaN    NaN
# 159              NaN    NaN
# 160              NaN    NaN
# 161              NaN    NaN
# 162              NaN    NaN
# 163              NaN    NaN
# 164              NaN    NaN
# 165              NaN    NaN
# 166              NaN    NaN
# 167              NaN    NaN
# 168              NaN    NaN
# 169              NaN    NaN
# 170              NaN    NaN
# 171              NaN    NaN
# 172              NaN    NaN
# 173              NaN    NaN
# 174              NaN    NaN
# 175              NaN    NaN
# 176              NaN    NaN
# 177              NaN    NaN
# 178              NaN    NaN
# 179              NaN    NaN
# 180              NaN    NaN
# 181              NaN    NaN
# 182              NaN    NaN
#
# [33 rows x 24 columns]

# %%
#%% Load OCT study information
octstudies = [];
folder_octexport_root = Path(r'\\file.corp.ghlabs.org\Shared\Projects\NAATOS\V1\NAATOS_OCT_WORK\OCTExport')
#folder_octexport_root = Path(r'D:\SGProjects\NAATOS\OCTlocal')

# Load list of data
for idx,record in dffilt.iterrows():
    octstudy = naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder(record['Test name'],folder_octexport_root);
    octstudies.append(octstudy);
# Out:
# STUDY: GHL_OldStriper_20250722T1202
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1206
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1213
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1216
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1220
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1223
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1226
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1229
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1232
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1235
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1239
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1243
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1254
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1257
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1300
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1303
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1306
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1309
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1312
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1318
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1339
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1342
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1348
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1351
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1354
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1357
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1400
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1403
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1406
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1409
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1413
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1418
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_OldStriper_20250722T1421
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}

# %%
# Master Parameters
oct_scalar_min = 30;
oct_scalar_max = 60;

# %%
#%% Load OCTSTUDY object, and start some processing on it
for idx,octstudy in enumerate(octstudies):
    octstudy : naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder;
    print(octstudy)

    fname_merged_and_rescaled_volume = octstudy.folder_study_processed/'{:s}_STACKED_RESCALED_{:}to{:}_uint8.vtk'.format(octstudy.name,oct_scalar_min,oct_scalar_max);
    
    if(octstudy.study_info['study_num_oct_files']>0):
        # --Loading And Pre-Processing--
        if(fname_merged_and_rescaled_volume.exists()):
            pass;
            #print(f'Loading {fname_merged_and_rescaled_volume.name}')
            # Load the strip and merge into one volume
            #vdvol = vedo.Volume(pv.read(fname_merged_and_rescaled_volume));
            #octstudy.vdvol = vdvol;
        else:
            # Load OCT Data for this study
            octstudy.load_all_octs();


            # THESE WILL DO NOTHING IF ANTICIPATED OUTPUTS/ARTIFACTS ALREADY EXIST IN THE PROCESSED FOLDER

            # RGB Camera Images - Write them out as .jpg to processed folder
            naatos_oct_tools.oct_linear_scan_processing.process_rgbcamera_and_make_individual_images(octstudy);

            # RGB Camera Images - Make a montage and write out as .jpg to processed folder
            naatos_oct_tools.oct_linear_scan_processing.process_rgbcamera_and_make_montage_image(octstudy);
            #break;


            # IF MERGED STACKED AND RESCALED TO SCALAR RANGE FILE EXISTS, LOAD THAT; OTHERWISE PROCESS IT HERE
            octstudy.folder_study_processed.mkdir(exist_ok=True);
            fname = fname_merged_and_rescaled_volume;
            if(fname.exists()):
                print('Stacked volume byte-size .vtk file already exists, will not recreate.');
                print(fname);
            else:
                print(f'Generating merged and rescaled .vtk volume');
                # Generate merged and rescaled volume
                vdvol = octstudy.generate_merged_vdvol_and_rescaled(oct_scalar_min,oct_scalar_max);
                octstudy.vdvol = vdvol;
            
                # save this byte-adjusted volume
                vdvol.dataset.save(fname);
                        
            # Unload OCT Data for this study (we will still keep the vdvol)
            octstudy.unload_all_octdata();

        # --Detailed Image Processing--
        if hasattr(octstudy,'vdvol'):
            del octstudy.vdvol;
# Out:
# <OCT_Study_Folder Object>
# GHL_OldStriper_20250722T1202 in folder //file.corp.ghlabs.org/Shared/Projects/NAATOS/V1/NAATOS_OCT_WORK/OCTExport
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# GHL_OldStriper_20250722T1202_videocamera_0000 20250722T120243
# GHL_OldStriper_20250722T1202_videocamera_0001 20250722T120253
# GHL_OldStriper_20250722T1202_videocamera_0002 20250722T120304
# GHL_OldStriper_20250722T1202_videocamera_0003 20250722T120315
# GHL_OldStriper_20250722T1202_videocamera_0004 20250722T120325
# GHL_OldStriper_20250722T1202_videocamera_0005 20250722T120336
# GHL_OldStriper_20250722T1202_videocamera_0006 20250722T120347
# GHL_OldStriper_20250722T1202_videocamera_0007 20250722T120358
# GHL_OldStriper_20250722T1202_videocamera_0008 20250722T120408
# GHL_OldStriper_20250722T1202_videocamera_0009 20250722T120419
# GHL_OldStriper_20250722T1202_videocamera_0010 20250722T120429
# GHL_OldStriper_20250722T1421_videocamera_0007 20250722T142212
# GHL_OldStriper_20250722T1421_videocamera_0008 20250722T142219
# GHL_OldStriper_20250722T1421_videocamera_0009 20250722T142227
# GHL_OldStriper_20250722T1421_videocamera_0010 20250722T142234
# GHL_OldStriper_20250722T1421_videocamera_0011 20250722T142242
# GHL_OldStriper_20250722T1421_videocamera_0012 20250722T142249
# GHL_OldStriper_20250722T1421_videocamera_0013 20250722T142257
# GHL_OldStriper_20250722T1421_videocamera_0014 20250722T142304
# GHL_OldStriper_20250722T1421_videocamera_0015 20250722T142312
# GHL_OldStriper_20250722T1421_videocamera_0016 20250722T142319
# GHL_OldStriper_20250722T1421_videocamera_0017 20250722T142327
# GHL_OldStriper_20250722T1421_videocamera_0018 20250722T142334
# millimeters Per Pixel X:48.33446705 Y:48.66782401
# OCT Scan Center Was @ [mm]: 0.0 -1.6
# OCT Scan FOV    Was @ [mm]: 9.0 3.5
# Video Camera Scan Pixel Width  [px]: 435.01020345
# Video Camera Scan Pixel Height [px]: 170.33738403499999
# Video Camera Scan Pixel Center X [px]: 0.0
# Video Camera Scan Pixel Center Y [px]: -77.868518416
#  SliceX  : slice(106.494898275, 541.505101725, None)
#  SliceY  : slice(233.8313079825, 404.1686920175, None)
# SliceXint: slice(106, 541, None)
# SliceYint: slice(233, 404, None)
# Generating merged and rescaled .vtk volume
# SingleFOV --> Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# Combined --> Image Dims:(575, 8550, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)

# %% [markdown]
# # (util) delete some items from processed folder

# %%
# Warning this can be destructive deleting processed data!!
if False:
    for idx,octstudy in enumerate(octstudies):
        print('~~~~~~~');
        print(octstudy.name);
        
        if False:
            fname = (octstudy.folder_study_processed/'along_strip_data_extracted.hdf5')
            if(fname.exists()):
                print('deleted',fname.name);
                fname.unlink();
            
            fname = (octstudy.folder_study_processed/'data_extracted.npz')
            if(fname.exists()):
                print('deleted',fname.name);
                fname.unlink();

            flist = octstudy.folder_study_processed.glob('figout*');
            for fname in flist:
                print('deleted',fname.name);
                fname.unlink();

            flist = octstudy.folder_study_processed.glob('processing_step*');
            for fname in flist:
                print('deleted',fname.name);
                fname.unlink();

        if True:
            # move files to a backup folder in the processed directory

            folder_backup = (octstudy.folder_study_processed/'_backup20250708');
            folder_backup.mkdir(exist_ok=True);

            fname = (octstudy.folder_study_processed/'along_strip_data_extracted.hdf5')
            if(fname.exists()):
                print('move to backup',fname.name);
                fname.rename(folder_backup/fname.name);
        
            fname = (octstudy.folder_study_processed/'data_extracted.npz')
            if(fname.exists()):
                print('move to backup',fname.name);
                fname.rename(folder_backup/fname.name);

            flist = octstudy.folder_study_processed.glob('figout*');
            for fname in flist:
                print('move to backup',fname.name);
                fname.rename(folder_backup/fname.name);

            flist = octstudy.folder_study_processed.glob('processing_step*');
            for fname in flist:
                print('move to backup',fname.name);
                fname.rename(folder_backup/fname.name);
        #break;

# %% [markdown]
# # (util) update excel index file

# %%
# Allow update of excel index file?
import openpyxl
workbook = None;
if False:
    # directly open excel file
    workbook = openpyxl.load_workbook(fname_excel);

    # open the proper sheet in the excel file
    #sheet = workbook.active
    sheet = workbook['Strip measurement'];

    # get the header
    hdrrow = 2;
    hdrcols = sheet[hdrrow];
    print(hdrcols)
    hdr = {c.value:cnt+1 for cnt,c in enumerate(hdrcols)};
    print(hdr)

    # go through each row, and look for matching octstudy object we have loaded in memory
    madeChanges = False;
    for row in sheet.iter_rows(min_row=hdrrow+3,min_col=hdrcols[0].column):
        record = {hdrcols[cnt].value:c.value for cnt,c in enumerate(row)}
        matchingoctstudy = [octstudy for octstudy in octstudies if octstudy.name==record["Test name"]]
        if len(matchingoctstudy)==1:
            print(record)
            print(octstudy.name)
            octstudy = matchingoctstudy[0]
            octstudy.load_first_oct();
            octdata = octstudy.octdatalist[0]
            cfg_oct_xml = octdata.cfg_oct_xml;

            # populate filesize
            row[hdr['Total size (GB)']-1].value = round(sum([f.stat().st_size for f in octstudy.folder_study.glob('*.oct')])/1e9,2);
            row[hdr['File size (MB)']-1].value = round((sum([f.stat().st_size for f in octstudy.folder_study.glob('*.oct')])/1e9)/octstudy.num_oct_files,2);

            # populate acquisition details
            pixelsize_x = float(cfg_oct_xml.Ocity.Image.PixelSpacing.SizeX.etElem.text)
            pixelsize_y = float(cfg_oct_xml.Ocity.Image.PixelSpacing.SizeY.etElem.text)
            pixelsize_z = float(cfg_oct_xml.Ocity.Image.PixelSpacing.SizeZ.etElem.text)
            totalsizemm_x = float(cfg_oct_xml.Ocity.Image.SizeReal.SizeX.etElem.text)
            totalsizemm_y = float(cfg_oct_xml.Ocity.Image.SizeReal.SizeY.etElem.text)
            totalsizemm_z = float(cfg_oct_xml.Ocity.Image.SizeReal.SizeZ.etElem.text)
            row[hdr['X, FOV']-1].value = totalsizemm_x;
            row[hdr['Y, FOV']-1].value = totalsizemm_y;
            row[hdr['Z, FOV']-1].value = totalsizemm_z;
            row[hdr['X, pixel size']-1].value = pixelsize_x*1e3;
            row[hdr['Y, pixel size']-1].value = pixelsize_y*1e3;
            row[hdr['Z, pixel size']-1].value = pixelsize_z*1e3;
            row[hdr['Angle']-1].value = float(cfg_oct_xml.Ocity.Image.Angle.etElem.text)
            row[hdr['Speed/Sensitivity']-1].value = cfg_oct_xml.Ocity.Instrument.DevicePresetDescription.etElem.text;
            row[hdr['Averaging (A-scan)']-1].value = int(cfg_oct_xml.Ocity.Acquisition.IntensityAveraging.AScans.etElem.text)
            row[hdr['Refractive Index']-1].value = round(float(cfg_oct_xml.Ocity.Acquisition.RefractiveIndex.etElem.text),1);

            if octstudy.has_json_info_file:
                jsoninfo = octstudy.json_info_file;
                row[hdr['Left edge (mm)']-1].value = jsoninfo['pos_leftmost_edge_center'];
                row[hdr['Right edge (mm)']-1].value = jsoninfo['pos_rightmost_edge_center'];
                row[hdr['Strip length (mm)']-1].value = jsoninfo['pos_rightmost_edge_center']-jsoninfo['pos_leftmost_edge_center'];

            # rescheck = octstudy.resultsCheck();
            # haveAllResults = not all([v is False for k,v in rescheck.items()])
            # #haveAllResults = haveAllResults and (len(rescheck['along_strip_data_extracted'])==5)
            # print('results done?',haveAllResults)
            # if(haveAllResults):
            #     row[hdr['ProcessingNotes']-1].value = 'done,{:d}'.format(len(rescheck['along_strip_data_extracted']))
            # else:
            #     row[hdr['ProcessingNotes']-1].value = ''
            # #break

            madeChanges = True

    if(madeChanges):
        # make a copy of the excel index
        fname_excel_copy = Path(fname_excel).parent/(Path(fname_excel).stem + time.strftime('_bak_%Y%m%dT%H%M.xlsx'))
        import shutil
        shutil.copy2(Path(fname_excel),fname_excel_copy);

        # then save the modified workbook on top of the old excel file
        workbook.save(fname_excel)
    else:
        print('No changes to excel index file made.');

    sheet.close();
    workbook.close();
# Out:
# (<Cell 'Strip measurement'.A2>, <Cell 'Strip measurement'.B2>, <Cell 'Strip measurement'.C2>, <Cell 'Strip measurement'.D2>, <Cell 'Strip measurement'.E2>, <Cell 'Strip measurement'.F2>, <Cell 'Strip measurement'.G2>, <Cell 'Strip measurement'.H2>, <Cell 'Strip measurement'.I2>, <Cell 'Strip measurement'.J2>, <Cell 'Strip measurement'.K2>, <Cell 'Strip measurement'.L2>, <Cell 'Strip measurement'.M2>, <Cell 'Strip measurement'.N2>, <Cell 'Strip measurement'.O2>, <Cell 'Strip measurement'.P2>, <Cell 'Strip measurement'.Q2>, <Cell 'Strip measurement'.R2>, <Cell 'Strip measurement'.S2>, <Cell 'Strip measurement'.T2>, <Cell 'Strip measurement'.U2>, <Cell 'Strip measurement'.V2>, <Cell 'Strip measurement'.W2>, <Cell 'Strip measurement'.X2>, <Cell 'Strip measurement'.Y2>)
# {None: 1, 'Test ID': 2, 'Test date': 3, 'Test name': 4, 'Batch': 5, 'Strip': 6, 'Wax (mg/mm)': 7, 'Fixture': 8, 'X, FOV': 9, 'Y, FOV': 10, 'Z, FOV': 11, 'X, pixel size': 12, 'Y, pixel size': 13, 'Z, pixel size': 14, 'Angle': 15, 'Right edge (mm)': 16, 'Left edge (mm)': 17, 'Strip length (mm)': 18, 'Speed/Sensitivity': 19, 'Averaging (A-scan)': 20, 'Refractive Index': 21, 'File size (MB)': 22, 'Total size (GB)': 23, 'ProcessingNotes': 24, 'Notes': 25}
# {None: None, 'Test ID': 145, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1202', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_1', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F153, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 4, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1421
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 146, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1206', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_1', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F154, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1202
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 147, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1213', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_3', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F155, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1206
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 148, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1216', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_7', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F156, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1213
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 149, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1220', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_35', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F157, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1216
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 150, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1223', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_33', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F158, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1220
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 151, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1226', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_31', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F159, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1223
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 152, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1229', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_29', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F160, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1226
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 153, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1232', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_27', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F161, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1229
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 154, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1235', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_25', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F162, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1232
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 155, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1239', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_22', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F163, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1235
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 156, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1243', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_19', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F164, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1239
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 157, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1254', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_17', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F165, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1243
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 158, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1257', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_16', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F166, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1254
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 159, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1300', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_15', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F167, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1257
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 160, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1303', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_14', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F168, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1300
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 161, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1306', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_13', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F169, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1303
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 162, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1309', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_12', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F170, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1306
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 163, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1312', 'Batch': 'July17n18Oldstriper', 'Strip': '7-18_8', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F171, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1309
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 164, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1318', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_14', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F172, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1312
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 165, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1339', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_8', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F173, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1318
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 166, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1342', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_3', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F174, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1339
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 167, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1348', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_42', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F175, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1342
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 168, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1351', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_45', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F176, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1348
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 169, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1354', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_46', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F177, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1351
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 170, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1357', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_32', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F178, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1354
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 171, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1400', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_30', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F179, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1357
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 172, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1403', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_28', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F180, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1400
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 173, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1406', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_26', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F181, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1403
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 174, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1409', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_23', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F182, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1406
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 175, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1413', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_21', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F183, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1409
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 176, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1418', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_19', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F184, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1413
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# {None: None, 'Test ID': 177, 'Test date': datetime.datetime(2025, 7, 22, 0, 0), 'Test name': 'GHL_OldStriper_20250722T1421', 'Batch': 'July17n18Oldstriper', 'Strip': '7-17_16', 'Wax (mg/mm)': '=_xlfn.NUMBERVALUE(_xlfn.TEXTAFTER(F185, " "))', 'Fixture': 'Vacuum', 'X, FOV': 9, 'Y, FOV': 3.5, 'Z, FOV': 1.998125, 'X, pixel size': 20, 'Y, pixel size': 20, 'Z, pixel size': 3.475, 'Angle': 0, 'Right edge (mm)': 297, 'Left edge (mm)': 131.8, 'Strip length (mm)': 165.2, 'Speed/Sensitivity': 'Default (Medium sensitivity, 48 kHz)', 'Averaging (A-scan)': 2, 'Refractive Index': 1.6, 'File size (MB)': 0.18, 'Total size (GB)': 3.46, 'ProcessingNotes': None, 'Notes': None}
# GHL_OldStriper_20250722T1418
# Image Dims:(575, 450, 175) PixelSpacing[mm]:(0.003475, 0.02, 0.02)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 83
#      80 else:
#      81     print('No changes to excel index file made.');
# ---> 83 sheet.close();
#      84 workbook.close();
#
# AttributeError: 'Worksheet' object has no attribute 'close'

# %% [markdown]
# # Call Notebooks - Processing A to D and E

# %%
#%% Load OCTSTUDY object, and start some processing on it
octstudies_to_run = [];
norunlist = [
    #'GHL_pyapp_20250508T1112','GHL_pyapp_20250508T1128','GHL_pyapp_20250508T1134','GHL_pyapp_20250508T1143'
]
forcerunlist = [
    #'GHL_pyapp_20250508T1151',
    #'GHL_pyapp_20250508T1601',
    #'GHL_pyapp_20250508T1608',
]
for idx,octstudy in enumerate(octstudies):
    octstudy : naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder;
    print('~~~~~~~');
    print(octstudy.name);
    rescheck = octstudy.resultsCheck();
    pp.pprint(rescheck)
    doWeRunTheNotebook = any([v is False for k,v in rescheck.items()])
    #doWeRunTheNotebook = doWeRunTheNotebook or ('/dfstepE' not in rescheck['along_strip_data_extracted']);
    doWeRunTheNotebook = doWeRunTheNotebook or ('/dfstepA' not in rescheck['along_strip_data_extracted']);
    print('Run?',doWeRunTheNotebook)
    if((doWeRunTheNotebook and octstudy.name not in norunlist) or (octstudy.name in forcerunlist)):
        octstudies_to_run.append(octstudy);
    # if(octstudy.name in forcerunlist):
    #     octstudies_to_run.append(octstudy);

# if(len(octstudies_to_run)>4):
#     #octstudies_to_run=octstudies_to_run[0:4];
#     #octstudies_to_run=octstudies_to_run[-4:];
#     print('only a subset');
#     norunlist = [
#         'GHL_pyapp_20250508T1112','GHL_pyapp_20250508T1128','GHL_pyapp_20250508T1134','GHL_pyapp_20250508T1143'
#     ]
#     octstudies_to_run = [s for s in octstudies_to_run if s.name not in norunlist ]
#     pass;

#octstudies_to_run = octstudies_to_run[0:20];

print('~~~~~~~');
print('We will run the processing on {:} octstudies.'.format(len(octstudies_to_run)))
print([x.name for x in octstudies_to_run])
# Out:
# ~~~~~~~
# GHL_OldStriper_20250722T1202
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1206
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1213
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1216
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1220
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1223
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1226
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1229
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1232
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1235
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1239
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1243
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1254
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1257
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1300
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1303
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1306
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1309
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1312
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1318
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1339
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1342
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1348
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1351
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1354
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1357
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1400
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1403
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1406
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1409
# {   'along_strip_data_extracted': ['/dfstepA'],
#     'exist_data_extracted': True,
#     'figoutmp4_stepA': True}
# Run? False
# ~~~~~~~
# GHL_OldStriper_20250722T1413
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1418
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# GHL_OldStriper_20250722T1421
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_stepA': False}
# Run? True
# ~~~~~~~
# We will run the processing on 18 octstudies.
# ['GHL_OldStriper_20250722T1206', 'GHL_OldStriper_20250722T1216', 'GHL_OldStriper_20250722T1220', 'GHL_OldStriper_20250722T1226', 'GHL_OldStriper_20250722T1232', 'GHL_OldStriper_20250722T1235', 'GHL_OldStriper_20250722T1254', 'GHL_OldStriper_20250722T1300', 'GHL_OldStriper_20250722T1303', 'GHL_OldStriper_20250722T1309', 'GHL_OldStriper_20250722T1312', 'GHL_OldStriper_20250722T1318', 'GHL_OldStriper_20250722T1354', 'GHL_OldStriper_20250722T1400', 'GHL_OldStriper_20250722T1406', 'GHL_OldStriper_20250722T1413', 'GHL_OldStriper_20250722T1418', 'GHL_OldStriper_20250722T1421']

# %% [markdown]
# # Prepare notebooks we will call

# %%
nbpaths = [
    #r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\octproc_20250615_process_a_longstrip.ipynb",
    #r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\octproc_20250721_process_a_longstrip.ipynb",
    r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\octproc_20250722_process_a_longstrip.ipynb",
];
for nbpath in nbpaths:
    print('Notebook:',Path(nbpath).name);
    parameters = papermill.inspect_notebook(nbpath)
    pp.pprint(parameters.keys());
# Out:
# Notebook: octproc_20250722_process_a_longstrip.ipynb
# dict_keys(['oct_scalar_min', 'oct_scalar_max', 'codename', 'study_name', 'folder_octexport_root', 'folder_figure_temp'])

# %% [markdown]
# # Call notebooks to process (Multiple-strips in parallel, concurrent futures)

# %%
import concurrent.futures

def run_notebook_on_an_octstudy(octstudy : naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder):

    folder_temp_path = Path(r'D:\TEMP\OCTtmp');
    folder_temp_path.mkdir(parents=True,exist_ok=True);

    # run each notebook we have defined to be run
    nnotebooks = len(nbpaths);
    for count,nbpath in enumerate(nbpaths):
        nbpath = Path(nbpath)
        nbpath_out = folder_temp_path/(nbpath.stem+'_OUT_{:s}.ipynb').format(octstudy.name)

        # execute a notebook
        print(f'Launching for {octstudy.name} the {count+1}/{nnotebooks} notebook {nbpath.name} ...')
        try:
            papermill.execute_notebook(
                input_path=nbpath,
                output_path=nbpath_out,
                parameters=dict(
                    folder_octexport_root=folder_octexport_root.as_posix(),
                    codename = Path(nbpath).name,
                    study_name=octstudy.name,
                    folder_figure_temp=nbpath_out.parent.as_posix()
                )
            )
            print(f'Finished for {octstudy.name} the {count+1}/{nnotebooks} notebook {nbpath.name} !')
        except Exception as e:
            print(f'FAILED for {octstudy.name} the {count+1}/{nnotebooks} notebook {nbpath.name} !')
            break;
    print(f'alldone for {octstudy.name}')


# Using concurrent.futures to handle multiprocessing
def run_in_parallel(num_processes):
    # with concurrent.futures.ProcessPoolExecutor(max_workers=num_processes) as executor:
    #     futures = [executor.submit(run_notebook_on_an_octstudy, octstudy) for octstudy in octstudies_to_run]
    #     for future in concurrent.futures.as_completed(futures):
    #         print(future.result())  # You can handle results or exceptions here
    with concurrent.futures.ThreadPoolExecutor(max_workers=num_processes) as executor:
        futures = [executor.submit(run_notebook_on_an_octstudy, octstudy) for octstudy in octstudies_to_run]
        for future in concurrent.futures.as_completed(futures):
            print(future.result());

# Example usage
num_processes = 6;  # Number of parallel processes
run_in_parallel(num_processes);
# Out:
# Launching for GHL_OldStriper_20250722T1206 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Launching for GHL_OldStriper_20250722T1216 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Launching for GHL_OldStriper_20250722T1220 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Launching for GHL_OldStriper_20250722T1226 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Launching for GHL_OldStriper_20250722T1232 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Launching for GHL_OldStriper_20250722T1235 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 9.68 sec, over 25% limit. Backing off to 60 sec
# Finished for GHL_OldStriper_20250722T1226 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1226
# None
# Launching for GHL_OldStriper_20250722T1254 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 15.13 sec, over 25% limit. Backing off to 120 sec
# Finished for GHL_OldStriper_20250722T1220 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1220
# None
# Launching for GHL_OldStriper_20250722T1300 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1235 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1235
# None
# Launching for GHL_OldStriper_20250722T1303 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1216 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1216
# None
# Launching for GHL_OldStriper_20250722T1309 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 8.14 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 10.49 sec, over 25% limit. Backing off to 60 sec
# Finished for GHL_OldStriper_20250722T1206 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1206
# None
# Launching for GHL_OldStriper_20250722T1312 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1232 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1232
# None
# Launching for GHL_OldStriper_20250722T1318 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1309 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1309
# None
# Launching for GHL_OldStriper_20250722T1354 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1303 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1303
# None
# Launching for GHL_OldStriper_20250722T1400 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1312 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1312
# None
# Launching for GHL_OldStriper_20250722T1406 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 11.52 sec, over 25% limit. Backing off to 60 sec
# Finished for GHL_OldStriper_20250722T1300 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1300
# None
# Launching for GHL_OldStriper_20250722T1413 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Autosave too slow: 7.57 sec, over 25% limit. Backing off to 60 sec
# Finished for GHL_OldStriper_20250722T1254 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1254
# None
# Launching for GHL_OldStriper_20250722T1418 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1318 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1318
# None
# Launching for GHL_OldStriper_20250722T1421 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/39 [00:00<?, ?cell/s]
# Finished for GHL_OldStriper_20250722T1354 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1354
# None
# Finished for GHL_OldStriper_20250722T1400 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1400
# None
# Finished for GHL_OldStriper_20250722T1413 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1413
# None
# Finished for GHL_OldStriper_20250722T1406 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1406
# None
# Finished for GHL_OldStriper_20250722T1418 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1418
# None
# Finished for GHL_OldStriper_20250722T1421 the 1/1 notebook octproc_20250722_process_a_longstrip.ipynb !
# alldone for GHL_OldStriper_20250722T1421
# None
