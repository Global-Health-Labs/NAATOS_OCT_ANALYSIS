# %% [markdown]
# # Process Multiple Long Strips

# %%
#%% imports
from pathlib import Path
# import json
# import configparser
import pprint
pp = pprint.PrettyPrinter(indent=4);
import time
import math
from collections import namedtuple

# # pip install slicerio
# import slicerio.server

# # packages for 3d
# #   # for OCT 3D stuff and using in jupyter
# #   - trame-jupyter-extension
# #   - trame
# #   - trame-vtk
# #   - trame-vuetify
# #   - ipywidgets

import matplotlib.pyplot as plt
import plotly.express as px

# interactive panels
import panel as pn
pn.extension('plotly');

import numpy as np
import pandas as pd
import addict

import cv2
import skimage
import scipy.signal

import pyvista as pv
from PIL import Image
import SimpleITK as sitk

# with vedo
#from vedo import dataurl, Volume, Text2D
import vedo
vedo.settings.default_backend = 'vtk'
#from vedo.applications import Slicer3DPlotter
import naatos_oct_tools.plotters.vedo_plotters as vedo_plotters
import naatos_oct_tools.plotters.sitk_plotters as sitk_plotters

import naatos_oct_tools.thorlabs_oct_file_reading
import naatos_oct_tools.oct_linear_scan_processing

import papermill
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='bc6caf48-30fa-4201-b978-1fa08e203593'>
#   <div id="d69bdd5e-bd86-4b3d-b2b9-fb89f7937f7e" data-root-id="bc6caf48-30fa-4201-b978-1fa08e203593" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f963ab2f-3cd4-4791-9d34-bfb17c57dbe1":{"version":"3.7.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"bc6caf48-30fa-4201-b978-1fa08e203593"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d5faa71b-472b-467e-b169-27f4ce5fd138","attributes":{"plot_id":"bc6caf48-30fa-4201-b978-1fa08e203593","comm_id":"5c0d045dda0b40658ea324259ba1e3ed","client_comm_id":"bd74a6b36cd4431c94f5d85915121c8b"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"f963ab2f-3cd4-4791-9d34-bfb17c57dbe1","roots":{"bc6caf48-30fa-4201-b978-1fa08e203593":"d69bdd5e-bd86-4b3d-b2b9-fb89f7937f7e"},"root_ids":["bc6caf48-30fa-4201-b978-1fa08e203593"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Plotly !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Magics to autoreload submodules when they are modified
# %load_ext autoreload
# %autoreload 2

# %%
#%% Test Record Excel
dftests = pd.read_excel(
    r'C:\Users\SimonGhionea\Global Health Labs, Inc\NAATOS Product Feasibility - TB V1 - General - Internal - Wax Valve\OCT\Test\OCT_wax_valve_test_record.xlsx',
    skiprows=1
)
dftests = dftests.iloc[:,1:]
dftests.rename(columns={'Unnamed: 19':'Notes'},inplace=True)
dftests
# Out:
#      Test ID  Test date                Test name  \
# 0        NaN 2025-03-26  GHL_pyapp_20250326T1258
# 1        NaN 2025-03-26  GHL_pyapp_20250326T1403
# 2        NaN 2025-03-26  GHL_pyapp_20250326T1416
# 3        NaN 2025-03-27  GHL_pyapp_20250327T1428
# 4        NaN 2025-03-27  GHL_pyapp_20250327T1438
# ..       ...        ...                      ...
# 118    113.0 2025-06-05  GHL_pyapp_20250605T1621
# 119    114.0 2025-06-05  GHL_pyapp_20250605T1625
# 120    115.0 2025-06-05  GHL_pyapp_20250605T1628
# 121    116.0 2025-06-05  GHL_pyapp_20250605T1633
# 122    117.0 2025-06-05  GHL_pyapp_20250605T1636
#
#                                        Batch                  Strip  \
# 0                      oven aging test day 1                strip 7
# 1                      oven aging test day 1               strip 10
# 2                      oven aging test day 1               strip 14
# 3                      oven aging test day 2                strip 7
# 4                      oven aging test day 2               strip 10
# ..                                       ...                    ...
# 118  Jun5 0.375-0.400mg/mm bag blu crossouts         ES0403#4 0.392
# 119  Jun5 0.375-0.400mg/mm bag blu crossouts  ES0403#1BluMark 0.382
# 120  Jun5 0.375-0.400mg/mm bag blu crossouts         ES0403#7 0.383
# 121  Jun5 0.375-0.400mg/mm bag blu crossouts        ES0402#14 0.384
# 122  Jun5 0.375-0.400mg/mm bag blu crossouts        ES0402#26 0.398
#
#      Wax (mg/mm)                    Fixture  X, FOV  Y, FOV  Z, FOV  ...  \
# 0            NaN             old, with tape     NaN     NaN     NaN  ...
# 1            NaN             old, with tape     NaN     NaN     NaN  ...
# 2            NaN             old, with tape     NaN     NaN     NaN  ...
# 3            NaN  old, with 3d print clamps     NaN     NaN     NaN  ...
# 4            NaN  old, with 3d print clamps     NaN     NaN     NaN  ...
# ..           ...                        ...     ...     ...     ...  ...
# 118        0.392                     Vacuum     NaN     NaN     NaN  ...
# 119        0.382                     Vacuum     NaN     NaN     NaN  ...
# 120        0.383                     Vacuum     NaN     NaN     NaN  ...
# 121        0.384                     Vacuum     NaN     NaN     NaN  ...
# 122        0.398                     Vacuum     NaN     NaN     NaN  ...
#
#      Right edge (mm)  Left edge (mm)  Strip length (mm)  Speed/Sensitivity  \
# 0                NaN             NaN                NaN                NaN
# 1                NaN             NaN                NaN                NaN
# 2                NaN             NaN                NaN                NaN
# 3                NaN             NaN                NaN                NaN
# 4                NaN             NaN                NaN                NaN
# ..               ...             ...                ...                ...
# 118              NaN             NaN                NaN                NaN
# 119              NaN             NaN                NaN                NaN
# 120              NaN             NaN                NaN                NaN
# 121              NaN             NaN                NaN                NaN
# 122              NaN             NaN                NaN                NaN
#
#      Averaging (A-scan)  Refractive Index  File size (MB) Total size (GB)  \
# 0                   NaN               NaN             NaN             NaN
# 1                   NaN               NaN             NaN             NaN
# 2                   NaN               NaN             NaN             NaN
# 3                   NaN               NaN             NaN             NaN
# 4                   NaN               NaN             NaN             NaN
# ..                  ...               ...             ...             ...
# 118                 NaN               NaN             NaN             NaN
# 119                 NaN               NaN             NaN             NaN
# 120                 NaN               NaN             NaN             NaN
# 121                 NaN               NaN             NaN             NaN
# 122                 NaN               NaN             NaN             NaN
#
#      ProcessingNotes  Notes
# 0                NaN    NaN
# 1                NaN    NaN
# 2                NaN    NaN
# 3                NaN    NaN
# 4                NaN    NaN
# ..               ...    ...
# 118           done,1    NaN
# 119           done,2    NaN
# 120          failed2    NaN
# 121           done,1    NaN
# 122           done,1    NaN
#
# [123 rows x 24 columns]

# %%
#%% Filter The Tests To Process
dfmasks = [
    dftests['Test date']=='2025-06-05',
    #dftests['Test name']!='GHL_pyapp_20250512T',
    dftests['ProcessingNotes'].str.startswith('done,2'),
    #~dftests['Batch'].str.contains('Valve')
]

dffilt = dftests[np.all(dfmasks,axis=0)]
dffilt
# Out:
#      Test ID  Test date                Test name  \
# 74      69.0 2025-06-05  GHL_pyapp_20250605T1211
# 80      75.0 2025-06-05  GHL_pyapp_20250605T1301
# 84      79.0 2025-06-05  GHL_pyapp_20250605T1336
# 89      84.0 2025-06-05  GHL_pyapp_20250605T1402
# 99      94.0 2025-06-05  GHL_pyapp_20250605T1440
# 106    101.0 2025-06-05  GHL_pyapp_20250605T1528
# 108    103.0 2025-06-05  GHL_pyapp_20250605T1536
# 109    104.0 2025-06-05  GHL_pyapp_20250605T1539
# 119    114.0 2025-06-05  GHL_pyapp_20250605T1625
#
#                                        Batch                   Strip  \
# 74             Jun5 0.325-0.349mg/mm bag ylw  BluePenES0323#16 0.335
# 80             Jun5 0.325-0.349mg/mm bag ylw         ES0403#30 0.345
# 84             Jun5 0.325-0.349mg/mm bag ylw          ES0401#4 0.325
# 89             Jun5 0.325-0.349mg/mm bag ylw          ES0401#6 0.329
# 99   Jun5 0.375-0.400mg/mm bag blu crossouts         ES0401#10 0.397
# 106  Jun5 0.375-0.400mg/mm bag blu crossouts         ES0410#22 0.397
# 108  Jun5 0.375-0.400mg/mm bag blu crossouts          ES0404#2 0.377
# 109  Jun5 0.375-0.400mg/mm bag blu crossouts         ES0404#10 0.385
# 119  Jun5 0.375-0.400mg/mm bag blu crossouts   ES0403#1BluMark 0.382
#
#      Wax (mg/mm) Fixture  X, FOV  Y, FOV  Z, FOV  ...  Right edge (mm)  \
# 74         0.335  Vacuum     NaN     NaN     NaN  ...              NaN
# 80         0.345  Vacuum     NaN     NaN     NaN  ...              NaN
# 84         0.325  Vacuum     NaN     NaN     NaN  ...              NaN
# 89         0.329  Vacuum     NaN     NaN     NaN  ...              NaN
# 99         0.397  Vacuum     NaN     NaN     NaN  ...              NaN
# 106        0.397  Vacuum     NaN     NaN     NaN  ...              NaN
# 108        0.377  Vacuum     NaN     NaN     NaN  ...              NaN
# 109        0.385  Vacuum     NaN     NaN     NaN  ...              NaN
# 119        0.382  Vacuum     NaN     NaN     NaN  ...              NaN
#
#      Left edge (mm)  Strip length (mm)  Speed/Sensitivity  Averaging (A-scan)  \
# 74              NaN                NaN                NaN                 NaN
# 80              NaN                NaN                NaN                 NaN
# 84              NaN                NaN                NaN                 NaN
# 89              NaN                NaN                NaN                 NaN
# 99              NaN                NaN                NaN                 NaN
# 106             NaN                NaN                NaN                 NaN
# 108             NaN                NaN                NaN                 NaN
# 109             NaN                NaN                NaN                 NaN
# 119             NaN                NaN                NaN                 NaN
#
#      Refractive Index  File size (MB) Total size (GB)  ProcessingNotes  Notes
# 74                NaN             NaN             NaN           done,2    NaN
# 80                NaN             NaN             NaN           done,2    NaN
# 84                NaN             NaN             NaN           done,2    NaN
# 89                NaN             NaN             NaN           done,2    NaN
# 99                NaN             NaN             NaN           done,2    NaN
# 106               NaN             NaN             NaN           done,2    NaN
# 108               NaN             NaN             NaN           done,2    NaN
# 109               NaN             NaN             NaN           done,2    NaN
# 119               NaN             NaN             NaN           done,2    NaN
#
# [9 rows x 24 columns]

# %%
#%% Load OCT study information
octstudies = [];
folder_octexport_root = Path(r'\\file.corp.ghlabs.org\Shared\Projects\NAATOS\V1\NAATOS_OCT_WORK\OCTExport')
#folder_octexport_root = Path(r'D:\SGProjects\NAATOS\OCTlocal')

# Load list of data
for idx,record in dffilt.iterrows():
    octstudy = naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder(record['Test name'],folder_octexport_root);
    octstudies.append(octstudy);
# Out:
# STUDY: GHL_pyapp_20250605T1211
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_pyapp_20250605T1301
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_pyapp_20250605T1336
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_pyapp_20250605T1402
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_pyapp_20250605T1440
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_pyapp_20250605T1528
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_pyapp_20250605T1536
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_pyapp_20250605T1539
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# STUDY: GHL_pyapp_20250605T1625
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}

# %%
# Master Parameters
oct_scalar_min = 30;
oct_scalar_max = 60;

# %%
#%% Load OCTSTUDY object, and start some processing on it
for idx,octstudy in enumerate(octstudies):
    octstudy : naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder;
    print(octstudy)

    fname_merged_and_rescaled_volume = octstudy.folder_study_processed/'{:s}_STACKED_RESCALED_{:}to{:}_uint8.vtk'.format(octstudy.name,oct_scalar_min,oct_scalar_max);
    
    if(octstudy.study_info['study_num_oct_files']>0):
        # --Loading And Pre-Processing--
        if(fname_merged_and_rescaled_volume.exists()):
            pass;
            #print(f'Loading {fname_merged_and_rescaled_volume.name}')
            # Load the strip and merge into one volume
            #vdvol = vedo.Volume(pv.read(fname_merged_and_rescaled_volume));
            #octstudy.vdvol = vdvol;
        else:
            # Load OCT Data for this study
            octstudy.load_all_octs();


            # THESE WILL DO NOTHING IF ANTICIPATED OUTPUTS/ARTIFACTS ALREADY EXIST IN THE PROCESSED FOLDER

            # RGB Camera Images - Write them out as .jpg to processed folder
            naatos_oct_tools.oct_linear_scan_processing.process_rgbcamera_and_make_individual_images(octstudy);

            # RGB Camera Images - Make a montage and write out as .jpg to processed folder
            naatos_oct_tools.oct_linear_scan_processing.process_rgbcamera_and_make_montage_image(octstudy);
            #break;


            # IF MERGED STACKED AND RESCALED TO SCALAR RANGE FILE EXISTS, LOAD THAT; OTHERWISE PROCESS IT HERE
            octstudy.folder_study_processed.mkdir(exist_ok=True);
            fname = fname_merged_and_rescaled_volume;
            if(fname.exists()):
                print('Stacked volume byte-size .vtk file already exists, will not recreate.');
                print(fname);
            else:
                print(f'Generating merged and rescaled .vtk volume');
                # Generate merged and rescaled volume
                vdvol = octstudy.generate_merged_vdvol_and_rescaled(oct_scalar_min,oct_scalar_max);
                octstudy.vdvol = vdvol;
            
                # save this byte-adjusted volume
                vdvol.dataset.save(fname);
            
            # Unload OCT Data for this study (we will still keep the vdvol)
            octstudy.unload_all_octdata();

        # --Detailed Image Processing--
        if hasattr(octstudy,'vdvol'):
            del octstudy.vdvol;
# Out:
# <OCT_Study_Folder Object>
# GHL_pyapp_20250605T1211 in folder //file.corp.ghlabs.org/Shared/Projects/NAATOS/V1/NAATOS_OCT_WORK/OCTExport
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# <OCT_Study_Folder Object>
# GHL_pyapp_20250605T1301 in folder //file.corp.ghlabs.org/Shared/Projects/NAATOS/V1/NAATOS_OCT_WORK/OCTExport
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# <OCT_Study_Folder Object>
# GHL_pyapp_20250605T1336 in folder //file.corp.ghlabs.org/Shared/Projects/NAATOS/V1/NAATOS_OCT_WORK/OCTExport
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# <OCT_Study_Folder Object>
# GHL_pyapp_20250605T1402 in folder //file.corp.ghlabs.org/Shared/Projects/NAATOS/V1/NAATOS_OCT_WORK/OCTExport
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# <OCT_Study_Folder Object>
# GHL_pyapp_20250605T1440 in folder //file.corp.ghlabs.org/Shared/Projects/NAATOS/V1/NAATOS_OCT_WORK/OCTExport
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# <OCT_Study_Folder Object>
# GHL_pyapp_20250605T1528 in folder //file.corp.ghlabs.org/Shared/Projects/NAATOS/V1/NAATOS_OCT_WORK/OCTExport
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# <OCT_Study_Folder Object>
# GHL_pyapp_20250605T1536 in folder //file.corp.ghlabs.org/Shared/Projects/NAATOS/V1/NAATOS_OCT_WORK/OCTExport
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# <OCT_Study_Folder Object>
# GHL_pyapp_20250605T1539 in folder //file.corp.ghlabs.org/Shared/Projects/NAATOS/V1/NAATOS_OCT_WORK/OCTExport
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}
# <OCT_Study_Folder Object>
# GHL_pyapp_20250605T1625 in folder //file.corp.ghlabs.org/Shared/Projects/NAATOS/V1/NAATOS_OCT_WORK/OCTExport
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}

# %% [markdown]
# # (util) delete some items from processed folder

# %%
# Warning this can be destructive deleting processed data!!
if False:
    for idx,octstudy in enumerate(octstudies):
        print('~~~~~~~');
        print(octstudy.name);
        
        # fname = (octstudy.folder_study_processed/'along_strip_data_extracted.hdf5')
        # if(fname.exists()):
        #     print('deleted',fname.name);
        #     fname.unlink();

        # flist = octstudy.folder_study_processed.glob('figout*');
        # for fname in flist:
        #     print('deleted',fname.name);
        #     fname.unlink();

        # flist = octstudy.folder_study_processed.glob('processing_step*');
        # for fname in flist:
        #     print('deleted',fname.name);
        #     fname.unlink();

        if True:
            # move files to a backup folder in the processed directory

            folder_backup = (octstudy.folder_study_processed/'_backup');
            folder_backup.mkdir(exist_ok=True);

            fname = (octstudy.folder_study_processed/'along_strip_data_extracted.hdf5')
            if(fname.exists()):
                print('move to backup',fname.name);
                fname.rename(folder_backup/fname.name);
        
            fname = (octstudy.folder_study_processed/'data_extracted.npz')
            if(fname.exists()):
                print('move to backup',fname.name);
                fname.rename(folder_backup/fname.name);

            flist = octstudy.folder_study_processed.glob('figout*');
            for fname in flist:
                print('move to backup',fname.name);
                fname.rename(folder_backup/fname.name);

            flist = octstudy.folder_study_processed.glob('processing_step*');
            for fname in flist:
                print('move to backup',fname.name);
                fname.rename(folder_backup/fname.name);
        #break;
# Out:
# ~~~~~~~
# GHL_pyapp_20250605T1211
# ~~~~~~~
# GHL_pyapp_20250605T1301
# move to backup along_strip_data_extracted.hdf5
# move to backup data_extracted.npz
# move to backup figout_post_maze_test.mp4
# move to backup figout_post_maze_test_connection_at_1020px.jpg
# move to backup figout_post_maze_test_connection_at_1585px.jpg
# move to backup figout_post_maze_test_connection_at_1590px.jpg
# move to backup figout_post_maze_test_connection_at_2910px.jpg
# move to backup figout_post_maze_test_connection_at_2940px.jpg
# move to backup figout_post_maze_test_connection_at_330px.jpg
# move to backup figout_post_maze_test_connection_at_3345px.jpg
# move to backup figout_post_maze_test_connection_at_3545px.jpg
# move to backup figout_post_maze_test_connection_at_3595px.jpg
# move to backup figout_post_maze_test_connection_at_3600px.jpg
# move to backup figout_post_maze_test_connection_at_3605px.jpg
# move to backup figout_post_maze_test_connection_at_3790px.jpg
# move to backup figout_post_maze_test_connection_at_3795px.jpg
# move to backup figout_post_maze_test_connection_at_3800px.jpg
# move to backup figout_post_maze_test_connection_at_3810px.jpg
# move to backup figout_post_maze_test_connection_at_3820px.jpg
# move to backup figout_post_maze_test_connection_at_4275px.jpg
# move to backup figout_post_maze_test_connection_at_4295px.jpg
# move to backup figout_post_maze_test_connection_at_4305px.jpg
# move to backup figout_post_maze_test_connection_at_4310px.jpg
# move to backup figout_post_maze_test_connection_at_4370px.jpg
# move to backup figout_post_maze_test_connection_at_4440px.jpg
# move to backup figout_post_maze_test_connection_at_4460px.jpg
# move to backup figout_post_maze_test_connection_at_4480px.jpg
# move to backup figout_post_maze_test_connection_at_4510px.jpg
# move to backup figout_post_maze_test_connection_at_4515px.jpg
# move to backup figout_post_maze_test_connection_at_4520px.jpg
# move to backup figout_post_maze_test_connection_at_4555px.jpg
# move to backup figout_post_maze_test_connection_at_5465px.jpg
# move to backup figout_post_maze_test_connection_at_5490px.jpg
# move to backup figout_post_maze_test_connection_at_5500px.jpg
# move to backup figout_post_maze_test_connection_at_6160px.jpg
# move to backup figout_post_maze_test_connection_at_6165px.jpg
# move to backup figout_post_maze_test_connection_at_6215px.jpg
# move to backup figout_post_maze_test_connection_at_6595px.jpg
# move to backup figout_post_maze_test_connection_at_6705px.jpg
# move to backup figout_post_maze_test_connection_at_6790px.jpg
# move to backup figout_post_maze_test_connection_at_8045px.jpg
# move to backup figout_post_maze_test_connection_at_8050px.jpg
# move to backup figout_post_maze_test_connection_at_8055px.jpg
# move to backup figout_stepA.mp4
# move to backup figout_stepB.mp4
# move to backup processing_step1a_20250608.jpg
# move to backup processing_step1b_20250608.jpg
# move to backup processing_step1c_20250608.jpg
# move to backup processing_step1d_20250608.jpg
# move to backup processing_step1e_20250608.jpg
# move to backup processing_step1f_20250608.jpg
# ~~~~~~~
# GHL_pyapp_20250605T1336
# move to backup along_strip_data_extracted.hdf5
# move to backup data_extracted.npz
# move to backup figout_stepA.mp4
# move to backup figout_stepB.mp4
# move to backup figout_post_maze_test_connection_at_1205px.jpg
# move to backup figout_post_maze_test_connection_at_3600px.jpg
# move to backup figout_post_maze_test_connection_at_4650px.jpg
# move to backup figout_post_maze_test_connection_at_5435px.jpg
# move to backup figout_post_maze_test.mp4
# move to backup processing_step1a_20250608.jpg
# move to backup processing_step1b_20250608.jpg
# move to backup processing_step1c_20250608.jpg
# move to backup processing_step1d_20250608.jpg
# move to backup processing_step1e_20250608.jpg
# move to backup processing_step1f_20250608.jpg
# ~~~~~~~
# GHL_pyapp_20250605T1402
# move to backup along_strip_data_extracted.hdf5
# move to backup data_extracted.npz
# move to backup figout_post_maze_test.mp4
# move to backup figout_post_maze_test_connection_at_1220px.jpg
# move to backup figout_post_maze_test_connection_at_1230px.jpg
# move to backup figout_post_maze_test_connection_at_1235px.jpg
# move to backup figout_post_maze_test_connection_at_1240px.jpg
# move to backup figout_post_maze_test_connection_at_1280px.jpg
# move to backup figout_post_maze_test_connection_at_1300px.jpg
# move to backup figout_post_maze_test_connection_at_1475px.jpg
# move to backup figout_post_maze_test_connection_at_1480px.jpg
# move to backup figout_post_maze_test_connection_at_1520px.jpg
# move to backup figout_post_maze_test_connection_at_1915px.jpg
# move to backup figout_post_maze_test_connection_at_1920px.jpg
# move to backup figout_post_maze_test_connection_at_1925px.jpg
# move to backup figout_post_maze_test_connection_at_2085px.jpg
# move to backup figout_post_maze_test_connection_at_2095px.jpg
# move to backup figout_post_maze_test_connection_at_2100px.jpg
# move to backup figout_post_maze_test_connection_at_2755px.jpg
# move to backup figout_post_maze_test_connection_at_3295px.jpg
# move to backup figout_post_maze_test_connection_at_3305px.jpg
# move to backup figout_post_maze_test_connection_at_4005px.jpg
# move to backup figout_post_maze_test_connection_at_4025px.jpg
# move to backup figout_post_maze_test_connection_at_4070px.jpg
# move to backup figout_post_maze_test_connection_at_4140px.jpg
# move to backup figout_post_maze_test_connection_at_4195px.jpg
# move to backup figout_post_maze_test_connection_at_4375px.jpg
# move to backup figout_post_maze_test_connection_at_4880px.jpg
# move to backup figout_post_maze_test_connection_at_4970px.jpg
# move to backup figout_post_maze_test_connection_at_5285px.jpg
# move to backup figout_post_maze_test_connection_at_6365px.jpg
# move to backup figout_post_maze_test_connection_at_675px.jpg
# move to backup figout_post_maze_test_connection_at_680px.jpg
# move to backup figout_post_maze_test_connection_at_690px.jpg
# move to backup figout_post_maze_test_connection_at_7100px.jpg
# move to backup figout_post_maze_test_connection_at_710px.jpg
# move to backup figout_post_maze_test_connection_at_7305px.jpg
# move to backup figout_post_maze_test_connection_at_750px.jpg
# move to backup figout_post_maze_test_connection_at_760px.jpg
# move to backup figout_post_maze_test_connection_at_7875px.jpg
# move to backup figout_post_maze_test_connection_at_7985px.jpg
# move to backup figout_post_maze_test_connection_at_8000px.jpg
# move to backup figout_post_maze_test_connection_at_900px.jpg
# move to backup figout_stepA.mp4
# move to backup figout_stepB.mp4
# move to backup processing_step1a_20250608.jpg
# move to backup processing_step1b_20250608.jpg
# move to backup processing_step1c_20250608.jpg
# move to backup processing_step1d_20250608.jpg
# move to backup processing_step1e_20250608.jpg
# move to backup processing_step1f_20250608.jpg
# ~~~~~~~
# GHL_pyapp_20250605T1440
# move to backup along_strip_data_extracted.hdf5
# move to backup data_extracted.npz
# move to backup figout_stepA.mp4
# move to backup figout_stepB.mp4
# move to backup figout_post_maze_test_connection_at_600px.jpg
# move to backup figout_post_maze_test_connection_at_1900px.jpg
# move to backup figout_post_maze_test_connection_at_4005px.jpg
# move to backup figout_post_maze_test_connection_at_5535px.jpg
# move to backup figout_post_maze_test_connection_at_5820px.jpg
# move to backup figout_post_maze_test_connection_at_5900px.jpg
# move to backup figout_post_maze_test_connection_at_5905px.jpg
# move to backup figout_post_maze_test_connection_at_5935px.jpg
# move to backup figout_post_maze_test_connection_at_5940px.jpg
# move to backup figout_post_maze_test_connection_at_6460px.jpg
# move to backup figout_post_maze_test_connection_at_6490px.jpg
# move to backup figout_post_maze_test_connection_at_7195px.jpg
# move to backup figout_post_maze_test_connection_at_7200px.jpg
# move to backup figout_post_maze_test_connection_at_7205px.jpg
# move to backup figout_post_maze_test_connection_at_7210px.jpg
# move to backup figout_post_maze_test_connection_at_7445px.jpg
# move to backup figout_post_maze_test.mp4
# move to backup processing_step1a_20250608.jpg
# move to backup processing_step1b_20250608.jpg
# move to backup processing_step1c_20250608.jpg
# move to backup processing_step1d_20250608.jpg
# move to backup processing_step1e_20250608.jpg
# move to backup processing_step1f_20250608.jpg
# ~~~~~~~
# GHL_pyapp_20250605T1528
# move to backup along_strip_data_extracted.hdf5
# move to backup data_extracted.npz
# move to backup figout_post_maze_test.mp4
# move to backup figout_post_maze_test_connection_at_1485px.jpg
# move to backup figout_post_maze_test_connection_at_625px.jpg
# move to backup figout_post_maze_test_connection_at_645px.jpg
# move to backup figout_post_maze_test_connection_at_650px.jpg
# move to backup figout_post_maze_test_connection_at_6815px.jpg
# move to backup figout_post_maze_test_connection_at_6915px.jpg
# move to backup figout_post_maze_test_connection_at_7275px.jpg
# move to backup figout_post_maze_test_connection_at_7500px.jpg
# move to backup figout_post_maze_test_connection_at_7555px.jpg
# move to backup figout_post_maze_test_connection_at_7600px.jpg
# move to backup figout_post_maze_test_connection_at_7610px.jpg
# move to backup figout_post_maze_test_connection_at_7980px.jpg
# move to backup figout_post_maze_test_connection_at_835px.jpg
# move to backup figout_post_maze_test_connection_at_845px.jpg
# move to backup figout_post_maze_test_connection_at_905px.jpg
# move to backup figout_stepA.mp4
# move to backup figout_stepB.mp4
# move to backup processing_step1a_20250608.jpg
# move to backup processing_step1b_20250608.jpg
# move to backup processing_step1c_20250608.jpg
# move to backup processing_step1d_20250608.jpg
# move to backup processing_step1e_20250608.jpg
# move to backup processing_step1f_20250608.jpg
# ~~~~~~~
# GHL_pyapp_20250605T1536
# move to backup along_strip_data_extracted.hdf5
# move to backup data_extracted.npz
# move to backup figout_post_maze_test.mp4
# move to backup figout_post_maze_test_connection_at_2080px.jpg
# move to backup figout_post_maze_test_connection_at_2300px.jpg
# move to backup figout_post_maze_test_connection_at_5120px.jpg
# move to backup figout_post_maze_test_connection_at_5175px.jpg
# move to backup figout_post_maze_test_connection_at_585px.jpg
# move to backup figout_post_maze_test_connection_at_6815px.jpg
# move to backup figout_post_maze_test_connection_at_7595px.jpg
# move to backup figout_post_maze_test_connection_at_8200px.jpg
# move to backup figout_stepA.mp4
# move to backup figout_stepB.mp4
# move to backup processing_step1a_20250608.jpg
# move to backup processing_step1b_20250608.jpg
# move to backup processing_step1c_20250608.jpg
# move to backup processing_step1d_20250608.jpg
# move to backup processing_step1e_20250608.jpg
# move to backup processing_step1f_20250608.jpg
# ~~~~~~~
# GHL_pyapp_20250605T1539
# move to backup along_strip_data_extracted.hdf5
# move to backup data_extracted.npz
# move to backup figout_post_maze_test.mp4
# move to backup figout_post_maze_test_connection_at_1990px.jpg
# move to backup figout_post_maze_test_connection_at_2015px.jpg
# move to backup figout_post_maze_test_connection_at_2025px.jpg
# move to backup figout_post_maze_test_connection_at_2040px.jpg
# move to backup figout_post_maze_test_connection_at_3190px.jpg
# move to backup figout_post_maze_test_connection_at_3350px.jpg
# move to backup figout_post_maze_test_connection_at_3355px.jpg
# move to backup figout_post_maze_test_connection_at_3405px.jpg
# move to backup figout_post_maze_test_connection_at_4345px.jpg
# move to backup figout_post_maze_test_connection_at_4540px.jpg
# move to backup figout_post_maze_test_connection_at_6005px.jpg
# move to backup figout_post_maze_test_connection_at_6010px.jpg
# move to backup figout_post_maze_test_connection_at_660px.jpg
# move to backup figout_post_maze_test_connection_at_665px.jpg
# move to backup figout_post_maze_test_connection_at_7985px.jpg
# move to backup figout_stepA.mp4
# move to backup figout_stepB.mp4
# move to backup processing_step1a_20250608.jpg
# move to backup processing_step1b_20250608.jpg
# move to backup processing_step1c_20250608.jpg
# move to backup processing_step1d_20250608.jpg
# move to backup processing_step1e_20250608.jpg
# move to backup processing_step1f_20250608.jpg
# ~~~~~~~
# GHL_pyapp_20250605T1625
# move to backup along_strip_data_extracted.hdf5
# move to backup data_extracted.npz
# move to backup figout_post_maze_test.mp4
# move to backup figout_post_maze_test_connection_at_100px.jpg
# move to backup figout_post_maze_test_connection_at_105px.jpg
# move to backup figout_post_maze_test_connection_at_10px.jpg
# move to backup figout_post_maze_test_connection_at_110px.jpg
# move to backup figout_post_maze_test_connection_at_115px.jpg
# move to backup figout_post_maze_test_connection_at_125px.jpg
# move to backup figout_post_maze_test_connection_at_130px.jpg
# move to backup figout_post_maze_test_connection_at_1355px.jpg
# move to backup figout_post_maze_test_connection_at_135px.jpg
# move to backup figout_post_maze_test_connection_at_140px.jpg
# move to backup figout_post_maze_test_connection_at_145px.jpg
# move to backup figout_post_maze_test_connection_at_150px.jpg
# move to backup figout_post_maze_test_connection_at_155px.jpg
# move to backup figout_post_maze_test_connection_at_160px.jpg
# move to backup figout_post_maze_test_connection_at_1655px.jpg
# move to backup figout_post_maze_test_connection_at_215px.jpg
# move to backup figout_post_maze_test_connection_at_220px.jpg
# move to backup figout_post_maze_test_connection_at_225px.jpg
# move to backup figout_post_maze_test_connection_at_230px.jpg
# move to backup figout_post_maze_test_connection_at_235px.jpg
# move to backup figout_post_maze_test_connection_at_2390px.jpg
# move to backup figout_post_maze_test_connection_at_240px.jpg
# move to backup figout_post_maze_test_connection_at_2410px.jpg
# move to backup figout_post_maze_test_connection_at_2420px.jpg
# move to backup figout_post_maze_test_connection_at_245px.jpg
# move to backup figout_post_maze_test_connection_at_255px.jpg
# move to backup figout_post_maze_test_connection_at_2695px.jpg
# move to backup figout_post_maze_test_connection_at_3080px.jpg
# move to backup figout_post_maze_test_connection_at_3340px.jpg
# move to backup figout_post_maze_test_connection_at_3510px.jpg
# move to backup figout_post_maze_test_connection_at_3520px.jpg
# move to backup figout_post_maze_test_connection_at_3920px.jpg
# move to backup figout_post_maze_test_connection_at_3925px.jpg
# move to backup figout_post_maze_test_connection_at_3930px.jpg
# move to backup figout_post_maze_test_connection_at_3955px.jpg
# move to backup figout_post_maze_test_connection_at_3960px.jpg
# move to backup figout_post_maze_test_connection_at_3965px.jpg
# move to backup figout_post_maze_test_connection_at_4000px.jpg
# move to backup figout_post_maze_test_connection_at_4065px.jpg
# move to backup figout_post_maze_test_connection_at_4070px.jpg
# move to backup figout_post_maze_test_connection_at_45px.jpg
# move to backup figout_post_maze_test_connection_at_4950px.jpg
# move to backup figout_post_maze_test_connection_at_4955px.jpg
# move to backup figout_post_maze_test_connection_at_4995px.jpg
# move to backup figout_post_maze_test_connection_at_5px.jpg
# move to backup figout_post_maze_test_connection_at_65px.jpg
# move to backup figout_post_maze_test_connection_at_70px.jpg
# move to backup figout_post_maze_test_connection_at_710px.jpg
# move to backup figout_post_maze_test_connection_at_7440px.jpg
# move to backup figout_post_maze_test_connection_at_7570px.jpg
# move to backup figout_post_maze_test_connection_at_75px.jpg
# move to backup figout_post_maze_test_connection_at_8080px.jpg
# move to backup figout_post_maze_test_connection_at_80px.jpg
# move to backup figout_post_maze_test_connection_at_8260px.jpg
# move to backup figout_post_maze_test_connection_at_85px.jpg
# move to backup figout_post_maze_test_connection_at_90px.jpg
# move to backup figout_stepA.mp4
# move to backup figout_stepB.mp4
# move to backup processing_step1a_20250609.jpg
# move to backup processing_step1b_20250609.jpg
# move to backup processing_step1c_20250609.jpg
# move to backup processing_step1d_20250609.jpg
# move to backup processing_step1e_20250609.jpg
# move to backup processing_step1f_20250609.jpg

# %% [markdown]
# # Call Notebooks - Processing A to D and E

# %%
#%% Load OCTSTUDY object, and start some processing on it
octstudies_to_run = [];
norunlist = [
    #'GHL_pyapp_20250508T1112','GHL_pyapp_20250508T1128','GHL_pyapp_20250508T1134','GHL_pyapp_20250508T1143'
]
forcerunlist = [
    #'GHL_pyapp_20250508T1151',
    #'GHL_pyapp_20250508T1601',
    #'GHL_pyapp_20250508T1608',
]
for idx,octstudy in enumerate(octstudies):
    octstudy : naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder;
    print('~~~~~~~');
    print(octstudy.name);
    rescheck = octstudy.resultsCheck();
    pp.pprint(rescheck)
    doWeRunTheNotebook = any([v is False for k,v in rescheck.items()])
    doWeRunTheNotebook = doWeRunTheNotebook or ('/dfstepE' not in rescheck['along_strip_data_extracted']);
    print('Run?',doWeRunTheNotebook)
    if((doWeRunTheNotebook and octstudy.name not in norunlist) or (octstudy.name in forcerunlist)):
        octstudies_to_run.append(octstudy);
    # if(octstudy.name in forcerunlist):
    #     octstudies_to_run.append(octstudy);

# if(len(octstudies_to_run)>4):
#     #octstudies_to_run=octstudies_to_run[0:4];
#     #octstudies_to_run=octstudies_to_run[-4:];
#     print('only a subset');
#     norunlist = [
#         'GHL_pyapp_20250508T1112','GHL_pyapp_20250508T1128','GHL_pyapp_20250508T1134','GHL_pyapp_20250508T1143'
#     ]
#     octstudies_to_run = [s for s in octstudies_to_run if s.name not in norunlist ]
#     pass;

#octstudies_to_run = octstudies_to_run[0:20];

print('~~~~~~~');
print('We will run the processing on {:} octstudies.'.format(len(octstudies_to_run)))
print([x.name for x in octstudies_to_run])
# Out:
# ~~~~~~~
# GHL_pyapp_20250605T1211
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_mazetest': False,
#     'figoutmp4_stepA': False,
#     'figoutmp4_stepB': False}
# Run? True
# ~~~~~~~
# GHL_pyapp_20250605T1301
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_mazetest': False,
#     'figoutmp4_stepA': False,
#     'figoutmp4_stepB': False}
# Run? True
# ~~~~~~~
# GHL_pyapp_20250605T1336
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_mazetest': False,
#     'figoutmp4_stepA': False,
#     'figoutmp4_stepB': False}
# Run? True
# ~~~~~~~
# GHL_pyapp_20250605T1402
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_mazetest': False,
#     'figoutmp4_stepA': False,
#     'figoutmp4_stepB': False}
# Run? True
# ~~~~~~~
# GHL_pyapp_20250605T1440
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_mazetest': False,
#     'figoutmp4_stepA': False,
#     'figoutmp4_stepB': False}
# Run? True
# ~~~~~~~
# GHL_pyapp_20250605T1528
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_mazetest': False,
#     'figoutmp4_stepA': False,
#     'figoutmp4_stepB': False}
# Run? True
# ~~~~~~~
# GHL_pyapp_20250605T1536
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_mazetest': False,
#     'figoutmp4_stepA': False,
#     'figoutmp4_stepB': False}
# Run? True
# ~~~~~~~
# GHL_pyapp_20250605T1539
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_mazetest': False,
#     'figoutmp4_stepA': False,
#     'figoutmp4_stepB': False}
# Run? True
# ~~~~~~~
# GHL_pyapp_20250605T1625
# {   'along_strip_data_extracted': False,
#     'exist_data_extracted': False,
#     'figoutmp4_mazetest': False,
#     'figoutmp4_stepA': False,
#     'figoutmp4_stepB': False}
# Run? True
# ~~~~~~~
# We will run the processing on 9 octstudies.
# ['GHL_pyapp_20250605T1211', 'GHL_pyapp_20250605T1301', 'GHL_pyapp_20250605T1336', 'GHL_pyapp_20250605T1402', 'GHL_pyapp_20250605T1440', 'GHL_pyapp_20250605T1528', 'GHL_pyapp_20250605T1536', 'GHL_pyapp_20250605T1539', 'GHL_pyapp_20250605T1625']

# %% [markdown]
# # Prepare notebooks we will call

# %%
#nbpath = r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\nb_test_nbparams.ipynb";
#nbpath = r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\octproc_20250429_process_a_longstrip.ipynb";
nbpaths = [
    r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\octproc_20250609_process_a_longstrip.ipynb",
    r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\octproc_20250507_process_E_longstripmetric.ipynb"
];
for nbpath in nbpaths:
    print('Notebook:',Path(nbpath).name);
    parameters = papermill.inspect_notebook(nbpath)
    pp.pprint(parameters.keys());
# Out:
# Notebook: octproc_20250609_process_a_longstrip.ipynb
# dict_keys(['oct_scalar_min', 'oct_scalar_max', 'codename', 'study_name', 'folder_octexport_root', 'folder_figure_temp'])
# Notebook: octproc_20250507_process_E_longstripmetric.ipynb
# dict_keys(['oct_scalar_min', 'oct_scalar_max', 'codename', 'folder_octexport_root', 'study_name', 'folder_figure_temp'])

# %% [markdown]
# # Call notebooks to process (Multiple-strips in parallel, concurrent futures)

# %%
import concurrent.futures

def run_notebook_on_an_octstudy(octstudy : naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder):

    folder_temp_path = Path(r'D:\TEMP\OCTtmp');
    folder_temp_path.mkdir(parents=True,exist_ok=True);

    # run each notebook we have defined to be run
    nnotebooks = len(nbpaths);
    for count,nbpath in enumerate(nbpaths):
        nbpath = Path(nbpath)
        nbpath_out = folder_temp_path/(nbpath.stem+'_OUT_{:s}.ipynb').format(octstudy.name)

        # execute a notebook
        print(f'Launching for {octstudy.name} the {count+1}/{nnotebooks} notebook {nbpath.name} ...')
        try:
            papermill.execute_notebook(
                input_path=nbpath,
                output_path=nbpath_out,
                parameters=dict(
                    folder_octexport_root=folder_octexport_root.as_posix(),
                    codename = Path(nbpath).name,
                    study_name=octstudy.name,
                    folder_figure_temp=nbpath_out.parent.as_posix()
                )
            )
            print(f'Finished for {octstudy.name} the {count+1}/{nnotebooks} notebook {nbpath.name} !')
        except Exception as e:
            print(f'FAILED for {octstudy.name} the {count+1}/{nnotebooks} notebook {nbpath.name} !')
            break;
    print(f'alldone for {octstudy.name}')


# Using concurrent.futures to handle multiprocessing
def run_in_parallel(num_processes):
    # with concurrent.futures.ProcessPoolExecutor(max_workers=num_processes) as executor:
    #     futures = [executor.submit(run_notebook_on_an_octstudy, octstudy) for octstudy in octstudies_to_run]
    #     for future in concurrent.futures.as_completed(futures):
    #         print(future.result())  # You can handle results or exceptions here
    with concurrent.futures.ThreadPoolExecutor(max_workers=num_processes) as executor:
        futures = [executor.submit(run_notebook_on_an_octstudy, octstudy) for octstudy in octstudies_to_run]
        for future in concurrent.futures.as_completed(futures):
            print(future.result());

# Example usage
num_processes = 3;  # Number of parallel processes
run_in_parallel(num_processes);
# Out:
# Launching for GHL_pyapp_20250605T1211 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb ...
# Launching for GHL_pyapp_20250605T1301 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb ...
# Launching for GHL_pyapp_20250605T1336 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/53 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/53 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/53 [00:00<?, ?cell/s]
# Autosave too slow: 75.81 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 3946.68 sec, over 25% limit. Backing off to 60 sec
# Autosave too slow: 3946.30 sec, over 25% limit. Backing off to 60 sec
# Finished for GHL_pyapp_20250605T1336 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb !
# Launching for GHL_pyapp_20250605T1336 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1301 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb !
# Launching for GHL_pyapp_20250605T1301 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1211 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb !
# Launching for GHL_pyapp_20250605T1211 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1336 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb !
# alldone for GHL_pyapp_20250605T1336
# None
# Launching for GHL_pyapp_20250605T1402 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/53 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1211 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb !
# alldone for GHL_pyapp_20250605T1211
# None
# Launching for GHL_pyapp_20250605T1440 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/53 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1301 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb !
# alldone for GHL_pyapp_20250605T1301
# Launching for GHL_pyapp_20250605T1528 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb ...
# None
# Executing:   0%|          | 0/53 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1402 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb !
# Launching for GHL_pyapp_20250605T1402 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1440 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb !
# Launching for GHL_pyapp_20250605T1440 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1528 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb !
# Launching for GHL_pyapp_20250605T1528 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1402 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb !
# alldone for GHL_pyapp_20250605T1402
# None
# Launching for GHL_pyapp_20250605T1536 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/53 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1440 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb !
# alldone for GHL_pyapp_20250605T1440
# None
# Launching for GHL_pyapp_20250605T1539 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/53 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1528 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb !
# alldone for GHL_pyapp_20250605T1528
# None
# Launching for GHL_pyapp_20250605T1625 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb ...
# Executing:   0%|          | 0/53 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1536 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb !
# Launching for GHL_pyapp_20250605T1536 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1536 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb !
# alldone for GHL_pyapp_20250605T1536
# None
# Finished for GHL_pyapp_20250605T1539 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb !
# Launching for GHL_pyapp_20250605T1539 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1625 the 1/2 notebook octproc_20250609_process_a_longstrip.ipynb !
# Launching for GHL_pyapp_20250605T1625 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]
# Finished for GHL_pyapp_20250605T1539 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb !
# alldone for GHL_pyapp_20250605T1539
# None
# Finished for GHL_pyapp_20250605T1625 the 2/2 notebook octproc_20250507_process_E_longstripmetric.ipynb !
# alldone for GHL_pyapp_20250605T1625
# None

# %%
import concurrent.futures
import time

def task(n):
    time.sleep(1)
    return n * n

# Using ThreadPoolExecutor
with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
    futures = [executor.submit(task, i) for i in range(10)]
    for future in concurrent.futures.as_completed(futures):
        print(future.result())

# # Using ProcessPoolExecutor
# with concurrent.futures.ProcessPoolExecutor(max_workers=5) as executor:
#     results = executor.map(task, range(10))
#     for result in results:
#         print(result)

# %% [markdown]
# # Call Notebooks - Processing E

# %%
#%% Load OCTSTUDY object, and start some processing on it
octstudies_to_run = [];
for idx,octstudy in enumerate(octstudies):
    octstudy : naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder;
    print('~~~~~~~');
    print(octstudy.name);
    rescheck = octstudy.resultsCheck();
    pp.pprint(rescheck);
    doWeRunTheNotebook = not any([v is False for k,v in rescheck.items()])
    doWeRunTheNotebook = doWeRunTheNotebook and ('/dfstepE' in rescheck['along_strip_data_extracted']);
    print('Run?',not doWeRunTheNotebook)
    if(not doWeRunTheNotebook):
        octstudies_to_run.append(octstudy);

print('~~~~~~~');
print('We will run the processing on {:} octstudies.'.format(len(octstudies_to_run)))
print([x.name for x in octstudies_to_run])

# %%
# Prepare notebook to run
import papermill

#nbpath = r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\nb_test_nbparams.ipynb";
#nbpath = r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\octproc_20250429_process_a_longstrip.ipynb";
nbpath = r"C:\Users\SimonGhionea\OneDrive - Global Health Labs, Inc\ProjectsCloud\NAATOS\sgpyanalysisoct\sandbox_sg\octproc_20250507_process_E_longstripmetric.ipynb";

parameters = papermill.inspect_notebook(nbpath)
pp.pprint(parameters);

# %%
# Call notebooks in parallel
import concurrent.futures

def run_notebook_on_an_octstudy(octstudy : naatos_oct_tools.thorlabs_oct_file_reading.OCT_Study_Folder):
    folder_temp_path = Path(r'D:\TEMP\OCTtmp');

    for nbpath in nbpaths:
        nbpath_out = folder_temp_path/(Path(nbpath).stem+'_OUT_{:s}.ipynb').format(octstudy.name)

    # set output path
    #nbpath_out = Path(nbpath).parent/(Path(nbpath).stem+'_OUT{:s}.ipynb').format(octstudy.name)
    nbpath_out = Path(r'C:\TEMP\OCTtmp')/(Path(nbpath).stem+'_OUT_{:s}.ipynb').format(octstudy.name)
    print(nbpath_out);

    # # execute a notebook
    papermill.execute_notebook(
        input_path=nbpath,
        output_path=nbpath_out,
        parameters=dict(codename = Path(nbpath).name,study_name=octstudy.name)
    )
    # print('start',octstudy.name);
    # time.sleep(1)
    # print('stop',octstudy.name)

# Using concurrent.futures to handle multiprocessing
def run_in_parallel(num_processes):
    # with concurrent.futures.ProcessPoolExecutor(max_workers=num_processes) as executor:
    #     futures = [executor.submit(run_notebook_on_an_octstudy, octstudy) for octstudy in octstudies_to_run]
    #     for future in concurrent.futures.as_completed(futures):
    #         print(future.result())  # You can handle results or exceptions here
    with concurrent.futures.ThreadPoolExecutor(max_workers=num_processes) as executor:
        futures = [executor.submit(run_notebook_on_an_octstudy, octstudy) for octstudy in octstudies_to_run]
        for future in concurrent.futures.as_completed(futures):
            print(future.result())

# Example usage
num_processes = 4;  # Number of parallel processes
run_in_parallel(num_processes);

# %% [markdown]
# # Processing Step 0 - Replace VTK scalars with scaled bytes

# %%
#del vdvol;
#del scalars_rescaled_as_int

# %% [markdown]
# # Develop VTK Range Rescaling and integer

# %%
def doVtkImageMinMaxScaling(vtkimagedata):
    # restrict range and re-scale, cast to integer (will reduce memory by 4x)
    oct_scalar_min = 30;
    oct_scalar_max = 60;

    import vtk

    # Create VTK Pipeline Connections
    # 1. Thresholding Hi
    alg_thresholder = vtk.vtkImageThreshold();
    alg_thresholder.SetInputData(vtkimagedata)
    alg_thresholder.ThresholdByUpper(oct_scalar_min);
    alg_thresholder.SetOutValue(oct_scalar_min);
    alg_thresholder.ReplaceInOff();
    alg_thresholder.ReplaceOutOn();

    # 2. Thresholding Lo
    alg_thresholder2 = vtk.vtkImageThreshold();
    alg_thresholder2.SetInputConnection(alg_thresholder.GetOutputPort());
    alg_thresholder2.ThresholdByLower(oct_scalar_max);
    alg_thresholder2.SetOutValue(oct_scalar_max);
    alg_thresholder2.ReplaceInOff();
    alg_thresholder2.ReplaceOutOn();

    # 3. Subtract Minimum Value
    alg_math1 = vtk.vtkImageMathematics();
    alg_math1.SetInputConnection(alg_thresholder2.GetOutputPort());
    alg_math1.SetConstantC(-oct_scalar_min);
    alg_math1.SetOperationToAddConstant();

    # 4. Rescale to 0 to 255
    alg_math2 = vtk.vtkImageMathematics();
    alg_math2.SetInputConnection(alg_math1.GetOutputPort());
    alg_math2.SetConstantK(255.0/oct_scalar_min);
    alg_math2.SetOperationToMultiplyByK();
    #cast to unit8_t byte
    #alg_math2.SetOutputS();

    # 5. Cast to Uint8
    alg_caster = vtk.vtkImageCast();
    alg_caster.SetInputConnection(alg_math2.GetOutputPort());
    alg_caster.SetOutputScalarTypeToUnsignedChar();


    # execute the vtk pipline, wrap with pyvista, and return
    alg_final = alg_caster;
    alg_final.Update();

    final = pv.wrap(alg_final.GetOutput())
    return final;
mergedvol_rescaled = doVtkImageMinMaxScaling(mergedvol);

# %%
np.max(mergedvol.active_scalars)

# %%
print(np.min(mergedvol_rescaled.active_scalars),np.max(mergedvol_rescaled.active_scalars))

# %%
mergedvol_rescaled['OCTintensity']

# %%
del mergedvol,mergedvol_rescaled,alg_thresholder

# %%
del alg_final
