# %% [markdown]
# # Test Panel Viewer For One Strip

# %%
#%% imports
from pathlib import Path
# import json
# import configparser
import pprint
pp = pprint.PrettyPrinter(indent=4);
import time
import math
from collections import namedtuple

# # pip install slicerio
# import slicerio.server

# # packages for 3d
# #   # for OCT 3D stuff and using in jupyter
# #   - trame-jupyter-extension
# #   - trame
# #   - trame-vtk
# #   - trame-vuetify
# #   - ipywidgets

import matplotlib.pyplot as plt
import plotly.express as px

# interactive panels
import panel as pn
pn.extension('plotly');

import numpy as np
import pandas as pd
import addict

import cv2
import skimage
import scipy.signal
import networkx as nx

import pyvista as pv
from PIL import Image
import SimpleITK as sitk

# with vedo
#from vedo import dataurl, Volume, Text2D
import vedo
vedo.settings.default_backend = 'vtk'
#from vedo.applications import Slicer3DPlotter
import naatos_oct_tools.plotters.vedo_plotters as vedo_plotters
import naatos_oct_tools.plotters.sitk_plotters as sitk_plotters

import naatos_oct_tools.thorlabs_oct_file_reading
import naatos_oct_tools.oct_linear_scan_processing
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1ea01c42-0cbc-46d5-94f7-4df2002e150c'>
#   <div id="d4f6b656-1278-4fe0-ad9c-33dfc573c182" data-root-id="1ea01c42-0cbc-46d5-94f7-4df2002e150c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Magics to autoreload submodules when they are modified
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 3. Examine ONE STRIP in detail

# %%
import naatos_oct_tools.panelui.singlestrip as singlestrip
obj3 = singlestrip.OCTSingleStripMetricViewer(
    #'GHL_pyapp_20250512T0947'
    #'GHL_pyapp_20250611T1709'
    #'GHL_pyapp_20250612T0752',

    'GHL_pyapp_20250605T1407', # bad strip 85 from 0609_build, used for specialized melting test 7/9/2025
    #'GHL_pyapp_20250605T1417', # bad strip 88 from 0609_build
    #'GHL_pyapp_20250605T1450', # bad strip 97 from 0609_build
);
# #fig = obj3._mkfig(use_millimeters=True);
# #fig.show(renderer='browser');
# Out:
# STUDY: GHL_pyapp_20250605T1407
# {   'study_has_an_ini_file': True,
#     'study_has_json_info_file': True,
#     'study_has_yat_log': False,
#     'study_num_jpg_files': 0,
#     'study_num_oct_files': 19,
#     'study_num_vtk_files': 0}

# %%
#sorted([x.name for x in list(obj3.octstudy.folder_study_processed.glob('processing_step1*.jpg'))],reverse=True)

# %%
#fig = obj3._mkfigure2();

# %%
#fig.show(renderer='browser');

# %%
obj3.servable();

# %% [markdown]
# # Experiment with video decoding and frame-seeking
#
# we will try to use decord library (https://github.com/dmlc/decord) for this

# %%
from decord import VideoReader
from decord import cpu, gpu

# %% [markdown]
# Create video reader object

# %%
# videopath = (obj3.octstudy.folder_study_processed/'figout_stepA.mp4').as_posix();
# vr = VideoReader(videopath, ctx=cpu(0));
# print('video frames:', len(vr))
# Out:
# video frames: 1652

# %%
# # get frame 100
# frame = vr[100]
# print(frame.shape)

# #it works!
# Out:
# (1200, 2000, 3)

# %%
# #px.imshow(frame.asnumpy())
# import holoviews as hv
# t = hv.RGB(frame.asnumpy())
# hv.render(t)
